# %%
#Import Dependencies
import os
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import requests
import datetime as dt
import seaborn as sns
import json

# %%
#get url
url="https://gbfs.bluebikes.com/gbfs/fr/station_information.json"

#perform request
response=requests.get(url)

# %%
print(response.url)
# Out:
# https://gbfs.bluebikes.com/gbfs/fr/station_information.json

# %%
data=response.json()

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "stations": [
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83464e4-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.34011512249236,
#                 "legacy_id": "3",
#                 "lon": -71.10061883926392,
#                 "name": "Colleges of the Fenway - Fenway at Avenue Louis Pasteur",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=3",
#                 "short_name": "B32006",
#                 "station_id": "3",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f834658f-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.345392,
#                 "legacy_id": "4",
#                 "lon": -71.069616,
#                 "name": "Tremont St at E Berkeley St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=4",
#                 "short_name": "C32000",
#                 "station_id": "4",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f834662c-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.341814,
#                 "legacy_id": "5",
#                 "lon": -71.090179,
#                 "name": "Northeastern University - North Parking Lot",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=5",
#                 "short_name": "B32012",
#                 "station_id": "5",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83466c6-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.36125721646537,
#                 "legacy_id": "6",
#                 "lon": -71.06528744101524,
#                 "name": "Cambridge St at Joy St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=6",
#                 "short_name": "D32000",
#                 "station_id": "6",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346768-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.3533905070523,
#                 "legacy_id": "7",
#                 "lon": -71.04457139968872,
#                 "name": "Fan Pier",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=7",
#                 "short_name": "A32000",
#                 "station_id": "7",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346803-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.353334,
#                 "legacy_id": "8",
#                 "lon": -71.137313,
#                 "name": "Union Square - Brighton Ave at Cambridge St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=8",
#                 "short_name": "A32001",
#                 "station_id": "8",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346894-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.35169201885973,
#                 "legacy_id": "9",
#                 "lon": -71.11903488636017,
#                 "name": "Commonwealth Ave at Agganis Way",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=9",
#                 "short_name": "A32002",
#                 "station_id": "9",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 11,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346a3c-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.350406,
#                 "legacy_id": "10",
#                 "lon": -71.108279,
#                 "name": "B.U. Central - 725 Comm. Ave.",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=10",
#                 "short_name": "A32003",
#                 "station_id": "10",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346ad7-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.338629,
#                 "legacy_id": "11",
#                 "lon": -71.1065,
#                 "name": "Longwood Ave at Binney St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=11",
#                 "short_name": "A32004",
#                 "station_id": "11",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 18,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346b6f-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.33624444796878,
#                 "legacy_id": "12",
#                 "lon": -71.08798563480377,
#                 "name": "Ruggles T Stop - Columbus Ave at Melnea Cass Blvd",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=12",
#                 "short_name": "B32002",
#                 "station_id": "12",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346c01-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.33639915372498,
#                 "legacy_id": "13",
#                 "lon": -71.07306711393903,
#                 "name": "Boston Medical Center - E Concord St at Harrison Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=13",
#                 "short_name": "C32002",
#                 "station_id": "13",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 25,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346c96-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.3374174845973,
#                 "legacy_id": "14",
#                 "lon": -71.10286116600037,
#                 "name": "HMS/HSPH - Avenue Louis Pasteur at Longwood Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=14",
#                 "short_name": "B32003",
#                 "station_id": "14",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346d23-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.3615457081725,
#                 "legacy_id": "15",
#                 "lon": -71.13776206970215,
#                 "name": "Brighton Mills - 370 Western Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=15",
#                 "short_name": "A32005",
#                 "station_id": "15",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346dbd-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.34807412317439,
#                 "legacy_id": "16",
#                 "lon": -71.07657015323639,
#                 "name": "Back Bay T Stop - Dartmouth St at Stuart St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=16",
#                 "short_name": "C32003",
#                 "station_id": "16",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346e51-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.364263440638524,
#                 "legacy_id": "17",
#                 "lon": -71.1182756971175,
#                 "name": "Soldiers Field Park - 111 Western Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=17",
#                 "short_name": "A32006",
#                 "station_id": "17",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8346f6f-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.347241,
#                 "legacy_id": "19",
#                 "lon": -71.105301,
#                 "name": "Park Dr at Buswell St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=19",
#                 "short_name": "A32008",
#                 "station_id": "19",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 23,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347002-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.35991176110118,
#                 "legacy_id": "20",
#                 "lon": -71.0514298081398,
#                 "name": "Aquarium T Stop - 200 Atlantic Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=20",
#                 "short_name": "B32004",
#                 "station_id": "20",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 18,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f834708e-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.34652003998412,
#                 "legacy_id": "21",
#                 "lon": -71.08065776545118,
#                 "name": "Prudential Center - 101 Huntington Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=21",
#                 "short_name": "C32007",
#                 "station_id": "21",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 47,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347118-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.352175,
#                 "legacy_id": "22",
#                 "lon": -71.055547,
#                 "name": "South Station - 700 Atlantic Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=22",
#                 "short_name": "A32010",
#                 "station_id": "22",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 21,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83471a1-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.35892,
#                 "legacy_id": "23",
#                 "lon": -71.057629,
#                 "name": "Boston City Hall - 28 State St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=23",
#                 "short_name": "B32008",
#                 "station_id": "23",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f834723b-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.35148193460858,
#                 "legacy_id": "24",
#                 "lon": -71.04436084628105,
#                 "name": "Seaport Square - Seaport Blvd at Northern Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=24",
#                 "short_name": "B32007",
#                 "station_id": "24",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83472d3-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.341332,
#                 "legacy_id": "25",
#                 "lon": -71.076847,
#                 "name": "South End Library - Tremont St at W Newton St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=25",
#                 "short_name": "A32009",
#                 "station_id": "25",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347361-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.341574718737476,
#                 "legacy_id": "26",
#                 "lon": -71.06890439987183,
#                 "name": "Washington St at Waltham St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=26",
#                 "short_name": "D32002",
#                 "station_id": "26",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 23,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83473ea-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.331184,
#                 "legacy_id": "27",
#                 "lon": -71.095171,
#                 "name": "Roxbury Crossing T Stop - Columbus Ave at Tremont St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=27",
#                 "short_name": "C32001",
#                 "station_id": "27",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347a8b-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.36314498882458,
#                 "legacy_id": "29",
#                 "lon": -71.12298574307715,
#                 "name": "Innovation Lab - 125 Western Ave at Batten Way",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=29",
#                 "short_name": "A32011",
#                 "station_id": "29",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347b1e-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.33462893055976,
#                 "legacy_id": "30",
#                 "lon": -71.10407917767589,
#                 "name": "Brigham Circle - Francis St at Huntington Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=30",
#                 "short_name": "B32013",
#                 "station_id": "30",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347ba8-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.34881026188269,
#                 "legacy_id": "31",
#                 "lon": -71.04167744055303,
#                 "name": "Seaport Hotel - Congress St at Seaport Ln",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=31",
#                 "short_name": "B32014",
#                 "station_id": "31",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347c41-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.343690557197476,
#                 "legacy_id": "32",
#                 "lon": -71.10235286881107,
#                 "name": "Landmark Center - Brookline Ave at Park Dr",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=32",
#                 "short_name": "B32015",
#                 "station_id": "32",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 27,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347ccd-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.348706,
#                 "legacy_id": "33",
#                 "lon": -71.097009,
#                 "name": "Kenmore Square",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=33",
#                 "short_name": "B32010",
#                 "station_id": "33",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 0,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347ded-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.355335019412564,
#                 "legacy_id": "35",
#                 "lon": -71.0582291708306,
#                 "name": "Arch St at Franklin St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=35",
#                 "short_name": "D32004",
#                 "station_id": "35",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 33,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347e78-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.34992828230057,
#                 "legacy_id": "36",
#                 "lon": -71.07739206866427,
#                 "name": "Copley Square - Dartmouth St at Boylston St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=36",
#                 "short_name": "D32005",
#                 "station_id": "36",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8347f09-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.35732921867706,
#                 "legacy_id": "37",
#                 "lon": -71.14673539996147,
#                 "name": "New Balance - 20 Guest St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=37",
#                 "short_name": "D32001",
#                 "station_id": "37",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 27,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348021-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.338514601785995,
#                 "legacy_id": "39",
#                 "lon": -71.07404083013535,
#                 "name": "Washington St at Rutland St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=39",
#                 "short_name": "C32006",
#                 "station_id": "39",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83480a9-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.363871,
#                 "legacy_id": "40",
#                 "lon": -71.050877,
#                 "name": "Lewis Wharf at Atlantic Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=40",
#                 "short_name": "D32006",
#                 "station_id": "40",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 27,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348136-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.352261,
#                 "legacy_id": "41",
#                 "lon": -71.123831,
#                 "name": "Packard's Corner - Commonwealth Ave at Brighton Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=41",
#                 "short_name": "A32012",
#                 "station_id": "41",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f834824e-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.357143,
#                 "legacy_id": "43",
#                 "lon": -71.050699,
#                 "name": "Rowes Wharf at Atlantic Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=43",
#                 "short_name": "D32008",
#                 "station_id": "43",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 23,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83482d2-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.36041774637169,
#                 "legacy_id": "44",
#                 "lon": -71.05752243543975,
#                 "name": "Congress St at Boston City Hall",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=44",
#                 "short_name": "D32009",
#                 "station_id": "44",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83483f3-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.3436658245146,
#                 "legacy_id": "46",
#                 "lon": -71.08582377433777,
#                 "name": "Christian Science Plaza - Massachusetts Ave at Westland Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=46",
#                 "short_name": "B32005",
#                 "station_id": "46",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348481-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.362811,
#                 "legacy_id": "47",
#                 "lon": -71.056067,
#                 "name": "Cross St at Hanover St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=47",
#                 "short_name": "D32010",
#                 "station_id": "47",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348509-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.35585435522005,
#                 "legacy_id": "48",
#                 "lon": -71.05459745998814,
#                 "name": "Post Office Square",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=48",
#                 "short_name": "D32012",
#                 "station_id": "48",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 18,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348598-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.351146,
#                 "legacy_id": "49",
#                 "lon": -71.066289,
#                 "name": "Stuart St at Charles St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=49",
#                 "short_name": "D32011",
#                 "station_id": "49",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348622-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.3511419825475,
#                 "legacy_id": "50",
#                 "lon": -71.07329249382019,
#                 "name": "Boylston St at Berkeley St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=50",
#                 "short_name": "D32013",
#                 "station_id": "50",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83486ab-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.3350989929096,
#                 "legacy_id": "51",
#                 "lon": -71.07903778553009,
#                 "name": "Washington St at Lenox St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=51",
#                 "short_name": "C32005",
#                 "station_id": "51",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 0,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348719-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.348717,
#                 "legacy_id": "52",
#                 "lon": -71.085954,
#                 "name": "Newbury St at Hereford St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=52",
#                 "short_name": "B32000",
#                 "station_id": "52",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348781-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.35082680669095,
#                 "legacy_id": "53",
#                 "lon": -71.0898108780384,
#                 "name": "Beacon St at Massachusetts Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=53",
#                 "short_name": "B32016",
#                 "station_id": "53",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83487f0-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.354979,
#                 "legacy_id": "54",
#                 "lon": -71.063348,
#                 "name": "Tremont St at West St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=54",
#                 "short_name": "D32014",
#                 "station_id": "54",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348857-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.34740620525209,
#                 "legacy_id": "55",
#                 "lon": -71.08678414955648,
#                 "name": "Boylston St at Massachusetts Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=55",
#                 "short_name": "B32018",
#                 "station_id": "55",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 18,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83488be-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.329842993518085,
#                 "legacy_id": "56",
#                 "lon": -71.08386572459494,
#                 "name": "Dudley Square - Bolling Building",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=56",
#                 "short_name": "B32017",
#                 "station_id": "56",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 14,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348924-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.33949453726166,
#                 "legacy_id": "57",
#                 "lon": -71.0802078062261,
#                 "name": "Massachusetts Ave at Columbus Ave",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=57",
#                 "short_name": "C32004",
#                 "station_id": "57",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348995-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.355536284897084,
#                 "legacy_id": "58",
#                 "lon": -71.07286870479584,
#                 "name": "Mugar Way at Beacon St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=58",
#                 "short_name": "D32017",
#                 "station_id": "58",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": true,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83489ff-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.351356,
#                 "legacy_id": "59",
#                 "lon": -71.059367,
#                 "name": "Chinatown Gate Plaza",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=59",
#                 "short_name": "D32015",
#                 "station_id": "59",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8348a68-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.36079296858265,
#                 "legacy_id": "60",
#                 "lon": -71.07118962337152,
#                 "name": "Charles Circle - Charles St at Cambridge St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=60",
#                 "short_name": "D32016",
#                 "station_id": "60",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f8349070-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.348762,
#                 "legacy_id": "61",
#                 "lon": -71.082383,
#                 "name": "Boylston St at Fairfield St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=61",
#                 "short_name": "C32008",
#                 "station_id": "61",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f834916a-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.344040510016356,
#                 "legacy_id": "63",
#                 "lon": -71.05737626552582,
#                 "name": "Dorchester Ave at Gillette Park",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=63",
#                 "short_name": "C32009",
#                 "station_id": "63",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83491d4-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.351004495946704,
#                 "legacy_id": "64",
#                 "lon": -71.04930013418198,
#                 "name": "Congress St at Sleeper St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=64",
#                 "short_name": "C32010",
#                 "station_id": "64",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 23,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f834923d-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.347763454147454,
#                 "legacy_id": "65",
#                 "lon": -71.0453599691391,
#                 "name": "Boston Convention and Exhibition Center - Summer St at West Side Dr",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=65",
#                 "short_name": "D32018",
#                 "station_id": "65",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f83492b4-0de8-11e7-991c-3863bb43a7d0",
#                 "has_kiosk": true,
#                 "lat": 42.34922469338298,
#                 "legacy_id": "66",
#                 "lon": -71.13275302578586,
#                 "name": "Commonwealth Ave at Griggs St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=66",
#                 "short_name": "A32017",
#                 "station_id": "66",
# ...
#                 "station_id": "480",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "868ccc83-99e5-4faf-96eb-e1fae26b9741",
#                 "has_kiosk": true,
#                 "lat": 42.341780891371904,
#                 "legacy_id": "481",
#                 "lon": -71.03987016504107,
#                 "name": "645 Summer St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=481",
#                 "short_name": "C32091",
#                 "station_id": "481",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 11,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "e68655be-23d3-46e5-a509-25be677e7542",
#                 "has_kiosk": true,
#                 "lat": 42.406161241322444,
#                 "legacy_id": "482",
#                 "lon": -71.06041654944418,
#                 "name": "Kearins Playground",
#                 "region_id": "104",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=482",
#                 "short_name": "V32013",
#                 "station_id": "482",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 17,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "3b158c7a-a362-43ae-af1f-121b78be32d7",
#                 "has_kiosk": true,
#                 "lat": 42.364119035231525,
#                 "legacy_id": "483",
#                 "lon": -71.02876782417297,
#                 "name": "Porzio Park",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=483",
#                 "short_name": "A32050",
#                 "station_id": "483",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 11,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "7feae3ce-ddf2-4a45-a123-1209c8a9182b",
#                 "has_kiosk": true,
#                 "lat": 42.408088,
#                 "legacy_id": "484",
#                 "lon": -71.008942,
#                 "name": "Revere Public Library",
#                 "region_id": "126",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=484",
#                 "short_name": "R32007",
#                 "station_id": "484",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 11,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "aa556ad4-0092-4687-96c2-8dbc69addb56",
#                 "has_kiosk": true,
#                 "lat": 42.40741,
#                 "legacy_id": "485",
#                 "lon": -71.0139,
#                 "name": "Revere City Hall",
#                 "region_id": "126",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=485",
#                 "short_name": "R32006",
#                 "station_id": "485",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 11,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "9340e113-e0b2-48ac-b58a-8b6f001b0a94",
#                 "has_kiosk": true,
#                 "lat": 42.330528,
#                 "legacy_id": "486",
#                 "lon": -71.192861,
#                 "name": "Langley Lot",
#                 "region_id": "127",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=486",
#                 "short_name": "N32008",
#                 "station_id": "486",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "380de8b2-2728-4e4b-83f1-251bfbb5acf2",
#                 "has_kiosk": true,
#                 "lat": 42.392525,
#                 "legacy_id": "487",
#                 "lon": -71.105587,
#                 "name": "Community Path at Lowell St",
#                 "region_id": "9",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=487",
#                 "short_name": "S32040",
#                 "station_id": "487",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 16,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "aefc33cd-40b9-48da-8b87-415428816bdb",
#                 "has_kiosk": true,
#                 "lat": 42.324173,
#                 "legacy_id": "488",
#                 "lon": -71.10196,
#                 "name": "Martha Eliot Health Center",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=488",
#                 "short_name": "E32012",
#                 "station_id": "488",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 16,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "f55cdf0a-3d7b-491c-bed2-7dc0ef2062d5",
#                 "has_kiosk": true,
#                 "lat": 42.379295,
#                 "legacy_id": "489",
#                 "lon": -71.027733,
#                 "name": "Day Sq",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=489",
#                 "short_name": "A32051",
#                 "station_id": "489",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 18,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "065e0e5d-8a0d-49b7-9c1f-c8eaba51a8b4",
#                 "has_kiosk": true,
#                 "lat": 42.286012,
#                 "legacy_id": "490",
#                 "lon": -71.090986,
#                 "name": "Blue Hill Ave at Havelock St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=490",
#                 "short_name": "C32092",
#                 "station_id": "490",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "50cc3c7f-50ed-4c70-b483-c89f3f47c938",
#                 "has_kiosk": true,
#                 "lat": 42.339194,
#                 "legacy_id": "491",
#                 "lon": -71.06975,
#                 "name": "Harrison Ave at E. Dedham St",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=491",
#                 "short_name": "C32093",
#                 "station_id": "491",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "0f554e1d-9f0f-452d-9b4a-e00aa2c5911e",
#                 "has_kiosk": true,
#                 "lat": 42.368019,
#                 "legacy_id": "492",
#                 "lon": -71.1242,
#                 "name": "Harvard Stadium: N. Harvard St at Soldiers Field Rd",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=492",
#                 "short_name": "A32052",
#                 "station_id": "492",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 17,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "efd724b2-31cb-4aec-b9d9-8ab79271630c",
#                 "has_kiosk": true,
#                 "lat": 42.28887,
#                 "legacy_id": "493",
#                 "lon": -71.095003,
#                 "name": "2 Hummingbird Lane at Olmsted Green",
#                 "region_id": "10",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=493",
#                 "short_name": "C32094",
#                 "station_id": "493",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 11,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "518f6524-0e7f-454d-974e-e3ff9db1f795",
#                 "has_kiosk": true,
#                 "lat": 42.367621,
#                 "legacy_id": "494",
#                 "lon": -71.187936,
#                 "name": "Watertown Town Hall",
#                 "region_id": "125",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=494",
#                 "short_name": "W32005",
#                 "station_id": "494",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "569f4952-5a25-4394-a419-f9c4d9cca6f3",
#                 "has_kiosk": true,
#                 "lat": 42.380078,
#                 "legacy_id": "495",
#                 "lon": -71.090098,
#                 "name": "Union Square East (Temp Winter Station)",
#                 "region_id": "9",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=495",
#                 "short_name": "S32041",
#                 "station_id": "495",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "603f7f65-e15c-44d7-9bce-581b5fda9a61",
#                 "has_kiosk": true,
#                 "lat": 42.398444,
#                 "legacy_id": "496",
#                 "lon": -71.107833,
#                 "name": "Trum Field @ Cedar St (Temp Winter Station)",
#                 "region_id": "9",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=496",
#                 "short_name": "S32042",
#                 "station_id": "496",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "d83f89ab-27f7-471e-a84b-e1a4d1582deb",
#                 "has_kiosk": true,
#                 "lat": 42.381056,
#                 "legacy_id": "497",
#                 "lon": -71.087083,
#                 "name": "Washington St @ New Washington St (Temp Winter Station)",
#                 "region_id": "9",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=497",
#                 "short_name": "S32043",
#                 "station_id": "497",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 15,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "b2b39507-9abd-41af-a5b2-b6e2ed8c3c4a",
#                 "has_kiosk": true,
#                 "lat": 42.396764,
#                 "legacy_id": "498",
#                 "lon": -71.102376,
#                 "name": "Broadway Opposite Norwood Ave  (Temp Winter Station)",
#                 "region_id": "9",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=498",
#                 "short_name": "S32044",
#                 "station_id": "498",
#                 "station_type": "classic"
#             },
#             {
#                 "capacity": 19,
#                 "eightd_has_key_dispenser": false,
#                 "eightd_station_services": [],
#                 "electric_bike_surcharge_waiver": false,
#                 "external_id": "b32131a5-0795-450f-ac27-0b5f4b56551d",
#                 "has_kiosk": true,
#                 "lat": 42.3836409294306,
#                 "legacy_id": "499",
#                 "lon": -71.10868692398071,
#                 "name": "Conway Park @ Bleachery Ct (Temp Winter Station)",
#                 "region_id": "9",
#                 "rental_methods": [
#                     "KEY",
#                     "CREDITCARD"
#                 ],
#                 "rental_url": "https://www.bluebikes.com/app?station_id=499",
#                 "short_name": "S32045",
#                 "station_id": "499",
#                 "station_type": "classic"
#             }
#         ]
#     },
#     "last_updated": 1607796560,
#     "ttl": 5
# }

# %%
#print station id, station_name, lat, long
