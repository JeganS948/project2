# %%
# import dependencies
import requests
import json
import pandas as pd
import numpy as np

# %%
# URL for Get requets to retireve data 
url = "https://vancouver-gbfs.smoove.pro/gbfs/en/station_information.json"

# %%
# print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# print JSON for all launchpads
x = requests.get(url).json()
print(json.dumps(x, indent=4, sort_keys=True))
# Out:
# {
#     "data": {
#         "stations": [
#             {
#                 "capacity": 32,
#                 "lat": 49.262487,
#                 "lon": -123.114397,
#                 "name": "10th & Cambie",
#                 "station_id": "0001"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.285871,
#                 "lon": -123.12105,
#                 "name": "Burrard Station (Melville & Dunsmuir)",
#                 "station_id": "0002"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.274566,
#                 "lon": -123.121817,
#                 "name": "Yaletown-Roundhouse Station",
#                 "station_id": "0004"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.279764,
#                 "lon": -123.110154,
#                 "name": "Dunsmuir & Beatty",
#                 "station_id": "0005"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.266314,
#                 "lon": -123.116011,
#                 "name": "Olympic Village Station",
#                 "station_id": "0006"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.260599,
#                 "lon": -123.113504,
#                 "name": "12th & Yukon (City Hall)",
#                 "station_id": "0007"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.264215,
#                 "lon": -123.117772,
#                 "name": "8th & Ash",
#                 "station_id": "0008"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.270877,
#                 "lon": -123.115103,
#                 "name": "Spyglass & Seawall",
#                 "station_id": "0009"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.26893,
#                 "lon": -123.11813,
#                 "name": "Stamps Landing",
#                 "station_id": "0010"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.271721,
#                 "lon": -123.104207,
#                 "name": "Ontario & Seawall",
#                 "station_id": "0011"
#             },
#             {
#                 "capacity": 24,
#                 "lat": 49.282214,
#                 "lon": -123.114101,
#                 "name": "Dunsmuir & Richards",
#                 "station_id": "0012"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.287214,
#                 "lon": -123.11287,
#                 "name": "Canada Place",
#                 "station_id": "0014"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.282409,
#                 "lon": -123.118541,
#                 "name": "Granville & Georgia",
#                 "station_id": "0015"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.287097,
#                 "lon": -123.118551,
#                 "name": "Pender & Burrard",
#                 "station_id": "0016"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.273471,
#                 "lon": -123.118016,
#                 "name": "Marinaside & Davie",
#                 "station_id": "0017"
#             },
#             {
#                 "capacity": 30,
#                 "lat": 49.282758,
#                 "lon": -123.122092,
#                 "name": "Robson & Hornby",
#                 "station_id": "0019"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.286042,
#                 "lon": -123.113176,
#                 "name": "Cordova & Granville",
#                 "station_id": "0021"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.28602,
#                 "lon": -123.116624,
#                 "name": "Hornby & Pender",
#                 "station_id": "0024"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.279739,
#                 "lon": -123.116251,
#                 "name": "Homer & Robson (Vancouver Public Library)",
#                 "station_id": "0025"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.277483,
#                 "lon": -123.114279,
#                 "name": "Beatty & Robson",
#                 "station_id": "0026"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.275679,
#                 "lon": -123.116963,
#                 "name": "Beatty & Nelson",
#                 "station_id": "0027"
#             },
#             {
#                 "capacity": 30,
#                 "lat": 49.287528,
#                 "lon": -123.142139,
#                 "name": "Davie & Beach",
#                 "station_id": "0028"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.282759,
#                 "lon": -123.106955,
#                 "name": "Abbott & Cordova",
#                 "station_id": "0030"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.28803,
#                 "lon": -123.142135,
#                 "name": "Morton & Denman",
#                 "station_id": "0031"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.288444,
#                 "lon": -123.139203,
#                 "name": "Comox & Denman",
#                 "station_id": "0032"
#             },
#             {
#                 "capacity": 24,
#                 "lat": 49.291285,
#                 "lon": -123.13526,
#                 "name": "Robson & Denman",
#                 "station_id": "0033"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.289124,
#                 "lon": -123.12196,
#                 "name": "Cordova & Bute",
#                 "station_id": "0034"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.290419,
#                 "lon": -123.12581,
#                 "name": "Coal Harbour Community Centre",
#                 "station_id": "0035"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.285836,
#                 "lon": -123.127265,
#                 "name": "Bute & Robson",
#                 "station_id": "0036"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.28062,
#                 "lon": -123.12482,
#                 "name": "Hornby & Nelson",
#                 "station_id": "0037"
#             },
#             {
#                 "capacity": 15,
#                 "lat": 49.279938,
#                 "lon": -123.127478,
#                 "name": "Helmcken & Burrard",
#                 "station_id": "0039"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.285876,
#                 "lon": -123.137728,
#                 "name": "Cardero & Pendrell",
#                 "station_id": "0040"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.289581,
#                 "lon": -123.132184,
#                 "name": "Cardero & Robson",
#                 "station_id": "0041"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.273663,
#                 "lon": -123.127075,
#                 "name": "Pacific & Richards",
#                 "station_id": "0044"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.275295,
#                 "lon": -123.132585,
#                 "name": "Beach & Hornby",
#                 "station_id": "0045"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.28972,
#                 "lon": -123.144028,
#                 "name": "Chilco & Beach",
#                 "station_id": "0047"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.285253,
#                 "lon": -123.134356,
#                 "name": "Comox & Broughton",
#                 "station_id": "0048"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.283343,
#                 "lon": -123.131099,
#                 "name": "Bute & Comox",
#                 "station_id": "0050"
#             },
#             {
#                 "capacity": 32,
#                 "lat": 49.284605,
#                 "lon": -123.108662,
#                 "name": "Cambie & Water",
#                 "station_id": "0052"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.279821,
#                 "lon": -123.10802,
#                 "name": "Keefer & Abbott",
#                 "station_id": "0053"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.278004,
#                 "lon": -123.105664,
#                 "name": "Expo & Carrall",
#                 "station_id": "0054"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.279342,
#                 "lon": -123.101822,
#                 "name": "Keefer & Columbia",
#                 "station_id": "0055"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.273833,
#                 "lon": -123.114373,
#                 "name": "Marinaside & Cooperage",
#                 "station_id": "0057"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.278283,
#                 "lon": -123.118612,
#                 "name": "Homer & Smithe",
#                 "station_id": "0058"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.28526,
#                 "lon": -123.141809,
#                 "name": "Bidwell & Burnaby",
#                 "station_id": "0060"
#             },
#             {
#                 "capacity": 30,
#                 "lat": 49.281506,
#                 "lon": -123.120101,
#                 "name": "Robson & Granville",
#                 "station_id": "0063"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.276115,
#                 "lon": -123.114496,
#                 "name": "Expo & Smithe",
#                 "station_id": "0064"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.272827,
#                 "lon": -123.147744,
#                 "name": "Cypress & Cornwall",
#                 "station_id": "0065"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.269361,
#                 "lon": -123.13782,
#                 "name": "Anderson & 2nd",
#                 "station_id": "0066"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.263507,
#                 "lon": -123.148097,
#                 "name": "Cypress & Broadway",
#                 "station_id": "0068"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.2653,
#                 "lon": -123.13811,
#                 "name": "7th & Granville",
#                 "station_id": "0069"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.262598,
#                 "lon": -123.138921,
#                 "name": "10th & Granville",
#                 "station_id": "0070"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.25894,
#                 "lon": -123.139272,
#                 "name": "14th & Granville",
#                 "station_id": "0071"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.258763,
#                 "lon": -123.115392,
#                 "name": "14th & Cambie",
#                 "station_id": "0072"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.266724,
#                 "lon": -123.104824,
#                 "name": "Ontario & 5th",
#                 "station_id": "0073"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.262141,
#                 "lon": -123.101961,
#                 "name": "10th & Main",
#                 "station_id": "0074"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.268269,
#                 "lon": -123.147885,
#                 "name": "Cypress & 4th",
#                 "station_id": "0076"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.275717,
#                 "lon": -123.142564,
#                 "name": "Vanier Park",
#                 "station_id": "0077"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.276436,
#                 "lon": -123.11877,
#                 "name": "Nelson & Mainland",
#                 "station_id": "0078"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.277844,
#                 "lon": -123.120942,
#                 "name": "Nelson & Richards",
#                 "station_id": "0079"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.263088,
#                 "lon": -123.12415,
#                 "name": "Laurel & Broadway",
#                 "station_id": "0080"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.265089,
#                 "lon": -123.119425,
#                 "name": "7th & Heather",
#                 "station_id": "0081"
#             },
#             {
#                 "capacity": 1,
#                 "lat": 49.276153,
#                 "lon": -123.123889,
#                 "name": "Richards & Davie - TEMP REMOVED",
#                 "station_id": "0082"
#             },
#             {
#                 "capacity": 35,
#                 "lat": 49.27821,
#                 "lon": -123.136972,
#                 "name": "Aquatic Centre",
#                 "station_id": "0083"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.281405,
#                 "lon": -123.139901,
#                 "name": "Sunset Beach West",
#                 "station_id": "0084"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.28329,
#                 "lon": -123.137034,
#                 "name": "Broughton & Burnaby",
#                 "station_id": "0087"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.28026,
#                 "lon": -123.135244,
#                 "name": "Harwood & Bute",
#                 "station_id": "0088"
#             },
#             {
#                 "capacity": 24,
#                 "lat": 49.27808,
#                 "lon": -123.130557,
#                 "name": "Burrard & Drake",
#                 "station_id": "0089"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.291909,
#                 "lon": -123.140713,
#                 "name": "Chilco & Barclay",
#                 "station_id": "0092"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.293257,
#                 "lon": -123.138563,
#                 "name": "Chilco & Robson",
#                 "station_id": "0093"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.288011,
#                 "lon": -123.132006,
#                 "name": "Nicola & Robson",
#                 "station_id": "0096"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.28117,
#                 "lon": -123.104419,
#                 "name": "Carrall & Hastings",
#                 "station_id": "0098"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.283227,
#                 "lon": -123.120523,
#                 "name": "Vancouver Art Gallery - North Plaza",
#                 "station_id": "0099"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.299292,
#                 "lon": -123.130281,
#                 "name": "Stanley Park - Vancouver Aquarium",
#                 "station_id": "0101"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.29534,
#                 "lon": -123.150433,
#                 "name": "Stanley Park - Second Beach North",
#                 "station_id": "0102"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.302577,
#                 "lon": -123.155616,
#                 "name": "Stanley Park - Third Beach Parking Lot",
#                 "station_id": "0103"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.294318,
#                 "lon": -123.148808,
#                 "name": "Stanley Park - Second Beach South",
#                 "station_id": "0104"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.298657,
#                 "lon": -123.121176,
#                 "name": "Stanley Park - Totem Poles",
#                 "station_id": "0105"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.259183,
#                 "lon": -123.120126,
#                 "name": "Heather & 14th",
#                 "station_id": "0106"
#             },
#             {
#                 "capacity": 15,
#                 "lat": 49.263837,
#                 "lon": -123.105173,
#                 "name": "8th & Ontario",
#                 "station_id": "0107"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.270721,
#                 "lon": -123.146175,
#                 "name": "1st & Chestnut",
#                 "station_id": "0108"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.265605,
#                 "lon": -123.152566,
#                 "name": "7th & Arbutus",
#                 "station_id": "0109"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.267222,
#                 "lon": -123.153157,
#                 "name": "5th & Arbutus",
#                 "station_id": "0110"
#             },
#             {
#                 "capacity": 30,
#                 "lat": 49.262255,
#                 "lon": -123.126217,
#                 "name": "10th & Oak",
#                 "station_id": "0112"
#             },
#             {
#                 "capacity": 40,
#                 "lat": 49.257654,
#                 "lon": -123.153212,
#                 "name": "Arbutus & 16th",
#                 "station_id": "0113"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.25919,
#                 "lon": -123.148268,
#                 "name": "Cypress & 14th",
#                 "station_id": "0114"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.25741,
#                 "lon": -123.148531,
#                 "name": "Cypress & 16th",
#                 "station_id": "0115"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.268216,
#                 "lon": -123.103168,
#                 "name": "3rd & Quebec",
#                 "station_id": "0119"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.285953,
#                 "lon": -123.124066,
#                 "name": "Georgia & Thurlow",
#                 "station_id": "0123"
#             },
#             {
#                 "capacity": 24,
#                 "lat": 49.284554,
#                 "lon": -123.111031,
#                 "name": "Richards & Cordova",
#                 "station_id": "0124"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.279611,
#                 "lon": -123.115056,
#                 "name": "Hamilton & Robson",
#                 "station_id": "0125"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.280881,
#                 "lon": -123.130672,
#                 "name": "Thurlow & Pendrell",
#                 "station_id": "0126"
#             },
#             {
#                 "capacity": 8,
#                 "lat": 49.280216,
#                 "lon": -123.117639,
#                 "name": "Richards & Robson - TEMP REMOVED",
#                 "station_id": "0129"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.256845,
#                 "lon": -123.120071,
#                 "name": "Heather & 16th",
#                 "station_id": "0130"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.25849,
#                 "lon": -123.104799,
#                 "name": "14th & Ontario",
#                 "station_id": "0132"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.256825,
#                 "lon": -123.105234,
#                 "name": "Ontario & 16th",
#                 "station_id": "0133"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.258425,
#                 "lon": -123.100792,
#                 "name": "14th & Main",
#                 "station_id": "0134"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.270905,
#                 "lon": -123.126006,
#                 "name": "David Lam Park - West",
#                 "station_id": "0136"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.273568,
#                 "lon": -123.129935,
#                 "name": "Beach & Seymour",
#                 "station_id": "0137"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.277141,
#                 "lon": -123.122589,
#                 "name": "Richards & Helmcken",
#                 "station_id": "0138"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.267859,
#                 "lon": -123.145782,
#                 "name": "Burrard & 4th",
#                 "station_id": "0139"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.265336,
#                 "lon": -123.145823,
#                 "name": "Burrard & 7th",
#                 "station_id": "0140"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.267628,
#                 "lon": -123.127698,
#                 "name": "South False Creek Seawall",
#                 "station_id": "0143"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.275938,
#                 "lon": -123.145939,
#                 "name": "Chestnut & McNicoll",
#                 "station_id": "0147"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.2756,
#                 "lon": -123.102661,
#                 "name": "Creekside Park North",
#                 "station_id": "0148"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.284157,
#                 "lon": -123.099917,
#                 "name": "Alexander & Main",
#                 "station_id": "0150"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.258924,
#                 "lon": -123.152591,
#                 "name": "Arbutus Greenway & 14th",
#                 "station_id": "0152"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.266774,
#                 "lon": -123.141135,
#                 "name": "Arbutus Greenway & Fir",
#                 "station_id": "0153"
#             },
#             {
#                 "capacity": 36,
#                 "lat": 49.273355,
#                 "lon": -123.154493,
#                 "name": "Kitsilano Beach Park",
#                 "station_id": "0154"
#             },
#             {
#                 "capacity": 30,
#                 "lat": 49.276144,
#                 "lon": -123.151272,
#                 "name": "Arbutus & McNicoll",
#                 "station_id": "0155"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.268339,
#                 "lon": -123.157443,
#                 "name": "Vine & 4th",
#                 "station_id": "0159"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.284062,
#                 "lon": -123.095097,
#                 "name": "Alexander & Dunlevy",
#                 "station_id": "0161"
#             },
#             {
#                 "capacity": 0,
#                 "lat": 49.26712,
#                 "lon": -123.10937,
#                 "name": "Columbia & 4th - TEMP REMOVED",
#                 "station_id": "0165"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.261742,
#                 "lon": -123.13148,
#                 "name": "Alder & 11th",
#                 "station_id": "0166"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.282266,
#                 "lon": -123.102165,
#                 "name": "Cordova & Columbia",
#                 "station_id": "0167"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.263962,
#                 "lon": -123.112621,
#                 "name": "8th & Yukon",
#                 "station_id": "0170"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.26667,
#                 "lon": -123.112414,
#                 "name": "5th & Yukon",
#                 "station_id": "0171"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.262206,
#                 "lon": -123.109091,
#                 "name": "10th & Columbia",
#                 "station_id": "0172"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.270218,
#                 "lon": -123.109189,
#                 "name": "1st & Columbia",
#                 "station_id": "0173"
#             },
#             {
#                 "capacity": 32,
#                 "lat": 49.27023,
#                 "lon": -123.10651,
#                 "name": "1st & Manitoba",
#                 "station_id": "0174"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.262062,
#                 "lon": -123.104656,
#                 "name": "10th & Ontario",
#                 "station_id": "0176"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.27033,
#                 "lon": -123.10275,
#                 "name": "Quebec & 1st",
#                 "station_id": "0177"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.261122,
#                 "lon": -123.097571,
#                 "name": "11th & Kingsway",
#                 "station_id": "0179"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.258902,
#                 "lon": -123.109596,
#                 "name": "Columbia & 14th",
#                 "station_id": "0180"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.261973,
#                 "lon": -123.09725,
#                 "name": "10th & Kingsway",
#                 "station_id": "0186"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.282224,
#                 "lon": -123.132778,
#                 "name": "Bute & Davie",
#                 "station_id": "0187"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.287782,
#                 "lon": -123.12395,
#                 "name": "Melville & Bute",
#                 "station_id": "0190"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.265071,
#                 "lon": -123.123864,
#                 "name": "7th & Laurel",
#                 "station_id": "0191"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.265198,
#                 "lon": -123.131043,
#                 "name": "7th &  Alder",
#                 "station_id": "0192"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.273691,
#                 "lon": -123.102232,
#                 "name": "Science World",
#                 "station_id": "0193"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.277213,
#                 "lon": -123.129625,
#                 "name": "Drake & Hornby",
#                 "station_id": "0196"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.2685027,
#                 "lon": -123.0975014,
#                 "name": "1st & Scotia",
#                 "station_id": "0197"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.266456,
#                 "lon": -123.100324,
#                 "name": "5th & Main",
#                 "station_id": "0198"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.278529,
#                 "lon": -123.100017,
#                 "name": "Georgia & Main",
#                 "station_id": "0199"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.288682,
#                 "lon": -123.11818,
#                 "name": "Shaw Tower",
#                 "station_id": "0201"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.258761,
#                 "lon": -123.127071,
#                 "name": "14th & Oak",
#                 "station_id": "0202"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.258864,
#                 "lon": -123.14353,
#                 "name": "Pine & 14th",
#                 "station_id": "0203"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.271741,
#                 "lon": -123.155421,
#                 "name": "York & Yew",
#                 "station_id": "0204"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.262822,
#                 "lon": -123.14338,
#                 "name": "Pine & 10th",
#                 "station_id": "0205"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.263635,
#                 "lon": -123.099236,
#                 "name": "8th & Scotia",
#                 "station_id": "0206"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.28763,
#                 "lon": -123.127245,
#                 "name": "Alberni & Jervis",
#                 "station_id": "0207"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.263649,
#                 "lon": -123.152421,
#                 "name": "Arbutus Greenway & Broadway",
#                 "station_id": "0208"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.297933,
#                 "lon": -123.130758,
#                 "name": "Stanley Park - Information Booth",
#                 "station_id": "0209"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.258819,
#                 "lon": -123.131317,
#                 "name": "14th & Alder",
#                 "station_id": "0211"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.277595,
#                 "lon": -123.09583,
#                 "name": "Union & Dunlevy",
#                 "station_id": "0212"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.280284,
#                 "lon": -123.097052,
#                 "name": "Pender & Gore",
#                 "station_id": "0213"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.277615,
#                 "lon": -123.091654,
#                 "name": "Princess & Union",
#                 "station_id": "0215"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.283325,
#                 "lon": -123.125249,
#                 "name": "Smithe & Burrard",
#                 "station_id": "0217"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.276294,
#                 "lon": -123.106534,
#                 "name": "Carrall & Seawall",
#                 "station_id": "0218"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.277333,
#                 "lon": -123.087359,
#                 "name": "Hawks & Union",
#                 "station_id": "0219"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.277469,
#                 "lon": -123.081315,
#                 "name": "Glen & Union",
#                 "station_id": "0221"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.277665,
#                 "lon": -123.073653,
#                 "name": "Adanac & McLean",
#                 "station_id": "0222"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.277436,
#                 "lon": -123.070427,
#                 "name": "Commercial & Adanac",
#                 "station_id": "0223"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.280332,
#                 "lon": -123.070068,
#                 "name": "Pender & Commercial",
#                 "station_id": "0224"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.280205,
#                 "lon": -123.074174,
#                 "name": "McLean & Pender",
#                 "station_id": "0225"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.280852,
#                 "lon": -123.084746,
#                 "name": "Campbell & Hastings",
#                 "station_id": "0227"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.279235,
#                 "lon": -123.087528,
#                 "name": "Keefer & Hawks",
#                 "station_id": "0228"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.279369,
#                 "lon": -123.091241,
#                 "name": "Keefer & Princess",
#                 "station_id": "0229"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.283992,
#                 "lon": -123.091206,
#                 "name": "Alexander & Railway",
#                 "station_id": "0230"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.274881,
#                 "lon": -123.069323,
#                 "name": "Napier & Commercial",
#                 "station_id": "0231"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.275882,
#                 "lon": -123.071865,
#                 "name": "Britannia Parking Lot",
#                 "station_id": "0232"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.273777,
#                 "lon": -123.092723,
#                 "name": "Thornton & National",
#                 "station_id": "0233"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.274249,
#                 "lon": -123.098481,
#                 "name": "Station & National",
#                 "station_id": "0234"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.273103,
#                 "lon": -123.069892,
#                 "name": "Charles & Commercial",
#                 "station_id": "0235"
#             },
#             {
#                 "capacity": 28,
#                 "lat": 49.265005,
#                 "lon": -123.079481,
#                 "name": "Keith & 6th",
#                 "station_id": "0236"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.265024,
#                 "lon": -123.08127,
#                 "name": "Glen & 6th",
#                 "station_id": "0237"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.267553,
#                 "lon": -123.094616,
#                 "name": "Thornton & 1st",
#                 "station_id": "0238"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.271377,
#                 "lon": -123.069416,
#                 "name": "Grant & Commercial",
#                 "station_id": "0239"
#             },
#             {
#                 "capacity": 22,
#                 "lat": 49.268616,
#                 "lon": -123.069908,
#                 "name": "2nd & Commercial",
#                 "station_id": "0240"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.266969,
#                 "lon": -123.069936,
#                 "name": "4th & Commercial",
#                 "station_id": "0241"
#             },
#             {
#                 "capacity": 38,
#                 "lat": 49.263242,
#                 "lon": -123.070521,
#                 "name": "8th & Commercial",
#                 "station_id": "0242"
#             },
#             {
#                 "capacity": 26,
#                 "lat": 49.261403,
#                 "lon": -123.070102,
#                 "name": "10th & Commercial",
#                 "station_id": "0244"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.261263,
#                 "lon": -123.073707,
#                 "name": "Woodland & 10th",
#                 "station_id": "0245"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.262242,
#                 "lon": -123.081459,
#                 "name": "Glen & Broadway",
#                 "station_id": "0246"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.262321,
#                 "lon": -123.09306,
#                 "name": "St George & Broadway",
#                 "station_id": "0248"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.264251,
#                 "lon": -123.073853,
#                 "name": "7th & Woodland",
#                 "station_id": "0249"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.266751,
#                 "lon": -123.073501,
#                 "name": "Woodland & 4th",
#                 "station_id": "0250"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.270684,
#                 "lon": -123.073562,
#                 "name": "Woodland & Graveley",
#                 "station_id": "0252"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.2731,
#                 "lon": -123.0732,
#                 "name": "Charles & Woodland",
#                 "station_id": "0253"
#             },
#             {
#                 "capacity": 42,
#                 "lat": 49.264083,
#                 "lon": -123.070611,
#                 "name": "Grandview Bike Lane & Commercial",
#                 "station_id": "0254"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.254667,
#                 "lon": -123.101389,
#                 "name": "18th & Main",
#                 "station_id": "0255"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.256694,
#                 "lon": -123.096579,
#                 "name": "Prince Edward & 16th",
#                 "station_id": "0256"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.258352,
#                 "lon": -123.096337,
#                 "name": "Prince Edward & 14th",
#                 "station_id": "0257"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.258817,
#                 "lon": -123.092797,
#                 "name": "13th & St George",
#                 "station_id": "0258"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.26151,
#                 "lon": -123.089413,
#                 "name": "10th & Fraser",
#                 "station_id": "0260"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.263382,
#                 "lon": -123.088837,
#                 "name": "8th & Fraser",
#                 "station_id": "0261"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.263518,
#                 "lon": -123.09568,
#                 "name": "8th & Prince Edward",
#                 "station_id": "0262"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.261353,
#                 "lon": -123.085333,
#                 "name": "St Catherines & 10th",
#                 "station_id": "0265"
#             },
#             {
#                 "capacity": 20,
#                 "lat": 49.264466,
#                 "lon": -123.085183,
#                 "name": "St Catherines & 7th",
#                 "station_id": "0266"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.280197,
#                 "lon": -123.065859,
#                 "name": "Pender & Victoria",
#                 "station_id": "0272"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.266725,
#                 "lon": -123.065925,
#                 "name": "Victoria & 4th",
#                 "station_id": "0273"
#             },
#             {
#                 "capacity": 12,
#                 "lat": 49.261188,
#                 "lon": -123.066009,
#                 "name": "Victoria & 10th",
#                 "station_id": "0274"
#             },
#             {
#                 "capacity": 18,
#                 "lat": 49.256857,
#                 "lon": -123.065646,
#                 "name": "15th & Victoria (Trout Lake)",
#                 "station_id": "0278"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.283986,
#                 "lon": -123.065264,
#                 "name": "Triumph & Victoria",
#                 "station_id": "0280"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.257985,
#                 "lon": -123.083366,
#                 "name": "Windsor & 14th",
#                 "station_id": "0281"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.257939,
#                 "lon": -123.089531,
#                 "name": "14th & Fraser",
#                 "station_id": "0282"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.256496,
#                 "lon": -123.075426,
#                 "name": "15th & Knight",
#                 "station_id": "0283"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.283236,
#                 "lon": -123.070443,
#                 "name": "Commercial & Pandora",
#                 "station_id": "0285"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.267266,
#                 "lon": -123.090786,
#                 "name": "Carolina & Great Northern Way",
#                 "station_id": "0287"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.265242,
#                 "lon": -123.095577,
#                 "name": "6th & Prince Edward",
#                 "station_id": "0297"
#             },
#             {
#                 "capacity": 16,
#                 "lat": 49.265213,
#                 "lon": -123.090785,
#                 "name": "6th & Carolina",
#                 "station_id": "0298"
#             },
#             {
#                 "capacity": 14,
#                 "lat": 49.284893,
#                 "lon": -123.128685,
#                 "name": "Bute & Barclay",
#                 "station_id": "0300"
#             }
#         ]
#     },
#     "last_updated": 1607793037,
#     "ttl": 60
# }

# %%
# create a list of stations
stations = x["data"]["stations"]
stations
# Out:
# [{'station_id': '0001',
#   'name': '10th & Cambie',
#   'lat': 49.262487,
#   'lon': -123.114397,
#   'capacity': 32},
#  {'station_id': '0002',
#   'name': 'Burrard Station (Melville & Dunsmuir)',
#   'lat': 49.285871,
#   'lon': -123.12105,
#   'capacity': 28},
#  {'station_id': '0004',
#   'name': 'Yaletown-Roundhouse Station',
#   'lat': 49.274566,
#   'lon': -123.121817,
#   'capacity': 16},
#  {'station_id': '0005',
#   'name': 'Dunsmuir & Beatty',
#   'lat': 49.279764,
#   'lon': -123.110154,
#   'capacity': 26},
#  {'station_id': '0006',
#   'name': 'Olympic Village Station',
#   'lat': 49.266314,
#   'lon': -123.116011,
#   'capacity': 26},
#  {'station_id': '0007',
#   'name': '12th & Yukon (City Hall)',
#   'lat': 49.260599,
#   'lon': -123.113504,
#   'capacity': 16},
#  {'station_id': '0008',
#   'name': '8th & Ash',
#   'lat': 49.264215,
#   'lon': -123.117772,
#   'capacity': 16},
#  {'station_id': '0009',
#   'name': 'Spyglass & Seawall',
#   'lat': 49.270877,
#   'lon': -123.115103,
#   'capacity': 14},
#  {'station_id': '0010',
#   'name': 'Stamps Landing',
#   'lat': 49.26893,
#   'lon': -123.11813,
#   'capacity': 14},
#  {'station_id': '0011',
#   'name': 'Ontario & Seawall',
#   'lat': 49.271721,
#   'lon': -123.104207,
#   'capacity': 20},
#  {'station_id': '0012',
#   'name': 'Dunsmuir & Richards',
#   'lat': 49.282214,
#   'lon': -123.114101,
#   'capacity': 24},
#  {'station_id': '0014',
#   'name': 'Canada Place',
#   'lat': 49.287214,
#   'lon': -123.11287,
#   'capacity': 26},
#  {'station_id': '0015',
#   'name': 'Granville & Georgia',
#   'lat': 49.282409,
#   'lon': -123.118541,
#   'capacity': 20},
#  {'station_id': '0016',
#   'name': 'Pender & Burrard',
#   'lat': 49.287097,
#   'lon': -123.118551,
#   'capacity': 26},
#  {'station_id': '0017',
#   'name': 'Marinaside & Davie',
#   'lat': 49.273471,
#   'lon': -123.118016,
#   'capacity': 22},
#  {'station_id': '0019',
#   'name': 'Robson & Hornby',
#   'lat': 49.282758,
#   'lon': -123.122092,
#   'capacity': 30},
#  {'station_id': '0021',
#   'name': 'Cordova & Granville',
#   'lat': 49.286042,
#   'lon': -123.113176,
#   'capacity': 22},
#  {'station_id': '0024',
#   'name': 'Hornby & Pender',
#   'lat': 49.28602,
#   'lon': -123.116624,
#   'capacity': 22},
#  {'station_id': '0025',
#   'name': 'Homer & Robson (Vancouver Public Library)',
#   'lat': 49.279739,
#   'lon': -123.116251,
#   'capacity': 20},
#  {'station_id': '0026',
#   'name': 'Beatty & Robson',
#   'lat': 49.277483,
#   'lon': -123.114279,
#   'capacity': 20},
#  {'station_id': '0027',
#   'name': 'Beatty & Nelson',
#   'lat': 49.275679,
#   'lon': -123.116963,
#   'capacity': 14},
#  {'station_id': '0028',
#   'name': 'Davie & Beach',
#   'lat': 49.287528,
#   'lon': -123.142139,
#   'capacity': 30},
#  {'station_id': '0030',
#   'name': 'Abbott & Cordova',
#   'lat': 49.282759,
#   'lon': -123.106955,
#   'capacity': 14},
#  {'station_id': '0031',
#   'name': 'Morton & Denman',
#   'lat': 49.28803,
#   'lon': -123.142135,
#   'capacity': 26},
#  {'station_id': '0032',
#   'name': 'Comox & Denman',
#   'lat': 49.288444,
#   'lon': -123.139203,
#   'capacity': 18},
#  {'station_id': '0033',
#   'name': 'Robson & Denman',
#   'lat': 49.291285,
#   'lon': -123.13526,
#   'capacity': 24},
#  {'station_id': '0034',
#   'name': 'Cordova & Bute',
#   'lat': 49.289124,
#   'lon': -123.12196,
#   'capacity': 14},
#  {'station_id': '0035',
#   'name': 'Coal Harbour Community Centre',
#   'lat': 49.290419,
#   'lon': -123.12581,
#   'capacity': 28},
#  {'station_id': '0036',
#   'name': 'Bute & Robson',
#   'lat': 49.285836,
#   'lon': -123.127265,
#   'capacity': 26},
#  {'station_id': '0037',
#   'name': 'Hornby & Nelson',
#   'lat': 49.28062,
#   'lon': -123.12482,
#   'capacity': 18},
#  {'station_id': '0039',
#   'name': 'Helmcken & Burrard',
#   'lat': 49.279938,
#   'lon': -123.127478,
#   'capacity': 15},
#  {'station_id': '0040',
#   'name': 'Cardero & Pendrell',
#   'lat': 49.285876,
#   'lon': -123.137728,
#   'capacity': 14},
#  {'station_id': '0041',
#   'name': 'Cardero & Robson',
#   'lat': 49.289581,
#   'lon': -123.132184,
#   'capacity': 14},
#  {'station_id': '0044',
#   'name': 'Pacific & Richards',
#   'lat': 49.273663,
#   'lon': -123.127075,
#   'capacity': 14},
#  {'station_id': '0045',
#   'name': 'Beach & Hornby',
#   'lat': 49.275295,
#   'lon': -123.132585,
#   'capacity': 18},
#  {'station_id': '0047',
#   'name': 'Chilco & Beach',
#   'lat': 49.28972,
#   'lon': -123.144028,
#   'capacity': 14},
#  {'station_id': '0048',
#   'name': 'Comox & Broughton',
#   'lat': 49.285253,
#   'lon': -123.134356,
#   'capacity': 12},
#  {'station_id': '0050',
#   'name': 'Bute & Comox',
#   'lat': 49.283343,
#   'lon': -123.131099,
#   'capacity': 22},
#  {'station_id': '0052',
#   'name': 'Cambie & Water',
#   'lat': 49.284605,
#   'lon': -123.108662,
#   'capacity': 32},
#  {'station_id': '0053',
#   'name': 'Keefer & Abbott',
#   'lat': 49.279821,
#   'lon': -123.10802,
#   'capacity': 28},
#  {'station_id': '0054',
#   'name': 'Expo & Carrall',
#   'lat': 49.278004,
#   'lon': -123.105664,
#   'capacity': 16},
#  {'station_id': '0055',
#   'name': 'Keefer & Columbia',
#   'lat': 49.279342,
#   'lon': -123.101822,
#   'capacity': 14},
#  {'station_id': '0057',
#   'name': 'Marinaside & Cooperage',
#   'lat': 49.273833,
#   'lon': -123.114373,
#   'capacity': 26},
#  {'station_id': '0058',
#   'name': 'Homer & Smithe',
#   'lat': 49.278283,
#   'lon': -123.118612,
#   'capacity': 18},
#  {'station_id': '0060',
#   'name': 'Bidwell & Burnaby',
#   'lat': 49.28526,
#   'lon': -123.141809,
#   'capacity': 26},
#  {'station_id': '0063',
#   'name': 'Robson & Granville',
#   'lat': 49.281506,
#   'lon': -123.120101,
#   'capacity': 30},
#  {'station_id': '0064',
#   'name': 'Expo & Smithe',
#   'lat': 49.276115,
#   'lon': -123.114496,
#   'capacity': 14},
#  {'station_id': '0065',
#   'name': 'Cypress & Cornwall',
#   'lat': 49.272827,
#   'lon': -123.147744,
#   'capacity': 22},
#  {'station_id': '0066',
#   'name': 'Anderson & 2nd',
#   'lat': 49.269361,
#   'lon': -123.13782,
#   'capacity': 28},
#  {'station_id': '0068',
#   'name': 'Cypress & Broadway',
#   'lat': 49.263507,
#   'lon': -123.148097,
#   'capacity': 14},
#  {'station_id': '0069',
#   'name': '7th & Granville',
#   'lat': 49.2653,
#   'lon': -123.13811,
#   'capacity': 14},
#  {'station_id': '0070',
#   'name': '10th & Granville',
#   'lat': 49.262598,
#   'lon': -123.138921,
#   'capacity': 14},
#  {'station_id': '0071',
#   'name': '14th & Granville',
#   'lat': 49.25894,
#   'lon': -123.139272,
#   'capacity': 14},
#  {'station_id': '0072',
#   'name': '14th & Cambie',
#   'lat': 49.258763,
#   'lon': -123.115392,
#   'capacity': 14},
#  {'station_id': '0073',
#   'name': 'Ontario & 5th',
#   'lat': 49.266724,
#   'lon': -123.104824,
#   'capacity': 18},
#  {'station_id': '0074',
#   'name': '10th & Main',
#   'lat': 49.262141,
#   'lon': -123.101961,
#   'capacity': 18},
#  {'station_id': '0076',
#   'name': 'Cypress & 4th',
#   'lat': 49.268269,
#   'lon': -123.147885,
#   'capacity': 18},
#  {'station_id': '0077',
#   'name': 'Vanier Park',
#   'lat': 49.275717,
#   'lon': -123.142564,
#   'capacity': 28},
#  {'station_id': '0078',
#   'name': 'Nelson & Mainland',
#   'lat': 49.276436,
#   'lon': -123.11877,
#   'capacity': 20},
#  {'station_id': '0079',
#   'name': 'Nelson & Richards',
#   'lat': 49.277844,
#   'lon': -123.120942,
#   'capacity': 18},
#  {'station_id': '0080',
#   'name': 'Laurel & Broadway',
#   'lat': 49.263088,
#   'lon': -123.12415,
#   'capacity': 14},
#  {'station_id': '0081',
#   'name': '7th & Heather',
#   'lat': 49.265089,
#   'lon': -123.119425,
#   'capacity': 18},
#  {'station_id': '0082',
#   'name': 'Richards & Davie - TEMP REMOVED',
#   'lat': 49.276153,
#   'lon': -123.123889,
#   'capacity': 1},
#  {'station_id': '0083',
#   'name': 'Aquatic Centre',
#   'lat': 49.27821,
#   'lon': -123.136972,
#   'capacity': 35},
#  {'station_id': '0084',
#   'name': 'Sunset Beach West',
#   'lat': 49.281405,
#   'lon': -123.139901,
#   'capacity': 16},
#  {'station_id': '0087',
#   'name': 'Broughton & Burnaby',
#   'lat': 49.28329,
#   'lon': -123.137034,
#   'capacity': 16},
#  {'station_id': '0088',
#   'name': 'Harwood & Bute',
#   'lat': 49.28026,
#   'lon': -123.135244,
#   'capacity': 20},
#  {'station_id': '0089',
#   'name': 'Burrard & Drake',
#   'lat': 49.27808,
#   'lon': -123.130557,
#   'capacity': 24},
#  {'station_id': '0092',
#   'name': 'Chilco & Barclay',
#   'lat': 49.291909,
#   'lon': -123.140713,
#   'capacity': 18},
#  {'station_id': '0093',
#   'name': 'Chilco & Robson',
#   'lat': 49.293257,
#   'lon': -123.138563,
#   'capacity': 18},
#  {'station_id': '0096',
#   'name': 'Nicola & Robson',
#   'lat': 49.288011,
#   'lon': -123.132006,
#   'capacity': 18},
#  {'station_id': '0098',
#   'name': 'Carrall & Hastings',
#   'lat': 49.28117,
#   'lon': -123.104419,
#   'capacity': 18},
#  {'station_id': '0099',
#   'name': 'Vancouver Art Gallery - North Plaza',
#   'lat': 49.283227,
#   'lon': -123.120523,
#   'capacity': 28},
#  {'station_id': '0101',
#   'name': 'Stanley Park - Vancouver Aquarium',
#   'lat': 49.299292,
#   'lon': -123.130281,
#   'capacity': 16},
#  {'station_id': '0102',
#   'name': 'Stanley Park - Second Beach North',
#   'lat': 49.29534,
#   'lon': -123.150433,
#   'capacity': 16},
#  {'station_id': '0103',
#   'name': 'Stanley Park - Third Beach Parking Lot',
#   'lat': 49.302577,
#   'lon': -123.155616,
#   'capacity': 28},
#  {'station_id': '0104',
#   'name': 'Stanley Park - Second Beach South',
#   'lat': 49.294318,
#   'lon': -123.148808,
#   'capacity': 18},
#  {'station_id': '0105',
#   'name': 'Stanley Park - Totem Poles',
#   'lat': 49.298657,
#   'lon': -123.121176,
#   'capacity': 20},
#  {'station_id': '0106',
#   'name': 'Heather & 14th',
#   'lat': 49.259183,
#   'lon': -123.120126,
#   'capacity': 16},
#  {'station_id': '0107',
#   'name': '8th & Ontario',
#   'lat': 49.263837,
#   'lon': -123.105173,
#   'capacity': 15},
#  {'station_id': '0108',
#   'name': '1st & Chestnut',
#   'lat': 49.270721,
#   'lon': -123.146175,
#   'capacity': 16},
#  {'station_id': '0109',
#   'name': '7th & Arbutus',
#   'lat': 49.265605,
#   'lon': -123.152566,
#   'capacity': 16},
#  {'station_id': '0110',
#   'name': '5th & Arbutus',
#   'lat': 49.267222,
#   'lon': -123.153157,
#   'capacity': 16},
#  {'station_id': '0112',
#   'name': '10th & Oak',
#   'lat': 49.262255,
#   'lon': -123.126217,
#   'capacity': 30},
#  {'station_id': '0113',
#   'name': 'Arbutus & 16th',
#   'lat': 49.257654,
#   'lon': -123.153212,
#   'capacity': 40},
#  {'station_id': '0114',
#   'name': 'Cypress & 14th',
#   'lat': 49.25919,
#   'lon': -123.148268,
#   'capacity': 12},
#  {'station_id': '0115',
#   'name': 'Cypress & 16th',
#   'lat': 49.25741,
#   'lon': -123.148531,
#   'capacity': 12},
#  {'station_id': '0119',
#   'name': '3rd & Quebec',
#   'lat': 49.268216,
#   'lon': -123.103168,
#   'capacity': 20},
#  {'station_id': '0123',
#   'name': 'Georgia & Thurlow',
#   'lat': 49.285953,
#   'lon': -123.124066,
#   'capacity': 12},
#  {'station_id': '0124',
#   'name': 'Richards & Cordova',
#   'lat': 49.284554,
#   'lon': -123.111031,
#   'capacity': 24},
#  {'station_id': '0125',
#   'name': 'Hamilton & Robson',
#   'lat': 49.279611,
#   'lon': -123.115056,
#   'capacity': 18},
#  {'station_id': '0126',
#   'name': 'Thurlow & Pendrell',
#   'lat': 49.280881,
#   'lon': -123.130672,
#   'capacity': 16},
#  {'station_id': '0129',
#   'name': 'Richards & Robson - TEMP REMOVED',
#   'lat': 49.280216,
#   'lon': -123.117639,
#   'capacity': 8},
#  {'station_id': '0130',
#   'name': 'Heather & 16th',
#   'lat': 49.256845,
#   'lon': -123.120071,
#   'capacity': 12},
#  {'station_id': '0132',
#   'name': '14th & Ontario',
#   'lat': 49.25849,
#   'lon': -123.104799,
#   'capacity': 16},
#  {'station_id': '0133',
#   'name': 'Ontario & 16th',
#   'lat': 49.256825,
#   'lon': -123.105234,
#   'capacity': 14},
#  {'station_id': '0134',
#   'name': '14th & Main',
#   'lat': 49.258425,
#   'lon': -123.100792,
#   'capacity': 14},
#  {'station_id': '0136',
#   'name': 'David Lam Park - West',
#   'lat': 49.270905,
#   'lon': -123.126006,
#   'capacity': 18},
#  {'station_id': '0137',
#   'name': 'Beach & Seymour',
#   'lat': 49.273568,
#   'lon': -123.129935,
#   'capacity': 18},
#  {'station_id': '0138',
#   'name': 'Richards & Helmcken',
#   'lat': 49.277141,
#   'lon': -123.122589,
#   'capacity': 18},
#  {'station_id': '0139',
#   'name': 'Burrard & 4th',
#   'lat': 49.267859,
#   'lon': -123.145782,
#   'capacity': 16},
#  {'station_id': '0140',
#   'name': 'Burrard & 7th',
#   'lat': 49.265336,
#   'lon': -123.145823,
#   'capacity': 16},
#  {'station_id': '0143',
#   'name': 'South False Creek Seawall',
#   'lat': 49.267628,
#   'lon': -123.127698,
#   'capacity': 14},
#  {'station_id': '0147',
#   'name': 'Chestnut & McNicoll',
#   'lat': 49.275938,
#   'lon': -123.145939,
#   'capacity': 16},
#  {'station_id': '0148',
#   'name': 'Creekside Park North',
#   'lat': 49.2756,
#   'lon': -123.102661,
#   'capacity': 18},
#  {'station_id': '0150',
#   'name': 'Alexander & Main',
#   'lat': 49.284157,
#   'lon': -123.099917,
#   'capacity': 20},
#  {'station_id': '0152',
#   'name': 'Arbutus Greenway & 14th',
#   'lat': 49.258924,
#   'lon': -123.152591,
#   'capacity': 20},
#  {'station_id': '0153',
#   'name': 'Arbutus Greenway & Fir',
#   'lat': 49.266774,
#   'lon': -123.141135,
#   'capacity': 16},
#  {'station_id': '0154',
#   'name': 'Kitsilano Beach Park',
#   'lat': 49.273355,
#   'lon': -123.154493,
#   'capacity': 36},
#  {'station_id': '0155',
#   'name': 'Arbutus & McNicoll',
#   'lat': 49.276144,
#   'lon': -123.151272,
#   'capacity': 30},
#  {'station_id': '0159',
#   'name': 'Vine & 4th',
#   'lat': 49.268339,
#   'lon': -123.157443,
#   'capacity': 18},
#  {'station_id': '0161',
#   'name': 'Alexander & Dunlevy',
#   'lat': 49.284062,
#   'lon': -123.095097,
#   'capacity': 14},
#  {'station_id': '0165',
#   'name': 'Columbia & 4th - TEMP REMOVED',
#   'lat': 49.26712,
#   'lon': -123.10937,
#   'capacity': 0},
#  {'station_id': '0166',
#   'name': 'Alder & 11th',
#   'lat': 49.261742,
#   'lon': -123.13148,
#   'capacity': 14},
#  {'station_id': '0167',
#   'name': 'Cordova & Columbia',
#   'lat': 49.282266,
#   'lon': -123.102165,
#   'capacity': 14},
#  {'station_id': '0170',
#   'name': '8th & Yukon',
#   'lat': 49.263962,
#   'lon': -123.112621,
#   'capacity': 14},
#  {'station_id': '0171',
#   'name': '5th & Yukon',
#   'lat': 49.26667,
#   'lon': -123.112414,
#   'capacity': 14},
#  {'station_id': '0172',
#   'name': '10th & Columbia',
#   'lat': 49.262206,
#   'lon': -123.109091,
#   'capacity': 14},
#  {'station_id': '0173',
#   'name': '1st & Columbia',
#   'lat': 49.270218,
#   'lon': -123.109189,
#   'capacity': 16},
#  {'station_id': '0174',
#   'name': '1st & Manitoba',
#   'lat': 49.27023,
#   'lon': -123.10651,
#   'capacity': 32},
#  {'station_id': '0176',
#   'name': '10th & Ontario',
#   'lat': 49.262062,
#   'lon': -123.104656,
#   'capacity': 20},
#  {'station_id': '0177',
#   'name': 'Quebec & 1st',
#   'lat': 49.27033,
#   'lon': -123.10275,
#   'capacity': 20},
#  {'station_id': '0179',
#   'name': '11th & Kingsway',
#   'lat': 49.261122,
#   'lon': -123.097571,
#   'capacity': 16},
#  {'station_id': '0180',
#   'name': 'Columbia & 14th',
#   'lat': 49.258902,
#   'lon': -123.109596,
#   'capacity': 14},
#  {'station_id': '0186',
#   'name': '10th & Kingsway',
#   'lat': 49.261973,
#   'lon': -123.09725,
#   'capacity': 20},
#  {'station_id': '0187',
#   'name': 'Bute & Davie',
#   'lat': 49.282224,
#   'lon': -123.132778,
#   'capacity': 16},
#  {'station_id': '0190',
#   'name': 'Melville & Bute',
#   'lat': 49.287782,
#   'lon': -123.12395,
#   'capacity': 14},
#  {'station_id': '0191',
#   'name': '7th & Laurel',
#   'lat': 49.265071,
#   'lon': -123.123864,
#   'capacity': 14},
#  {'station_id': '0192',
#   'name': '7th &  Alder',
#   'lat': 49.265198,
#   'lon': -123.131043,
#   'capacity': 16},
#  {'station_id': '0193',
#   'name': 'Science World',
#   'lat': 49.273691,
#   'lon': -123.102232,
#   'capacity': 16},
#  {'station_id': '0196',
#   'name': 'Drake & Hornby',
#   'lat': 49.277213,
#   'lon': -123.129625,
#   'capacity': 22},
#  {'station_id': '0197',
#   'name': '1st & Scotia',
#   'lat': 49.2685027,
#   'lon': -123.0975014,
#   'capacity': 20},
#  {'station_id': '0198',
#   'name': '5th & Main',
#   'lat': 49.266456,
#   'lon': -123.100324,
#   'capacity': 20},
#  {'station_id': '0199',
#   'name': 'Georgia & Main',
#   'lat': 49.278529,
#   'lon': -123.100017,
#   'capacity': 20},
#  {'station_id': '0201',
#   'name': 'Shaw Tower',
#   'lat': 49.288682,
#   'lon': -123.11818,
#   'capacity': 20},
#  {'station_id': '0202',
#   'name': '14th & Oak',
#   'lat': 49.258761,
#   'lon': -123.127071,
#   'capacity': 14},
#  {'station_id': '0203',
#   'name': 'Pine & 14th',
#   'lat': 49.258864,
#   'lon': -123.14353,
#   'capacity': 12},
#  {'station_id': '0204',
#   'name': 'York & Yew',
#   'lat': 49.271741,
#   'lon': -123.155421,
#   'capacity': 20},
#  {'station_id': '0205',
#   'name': 'Pine & 10th',
#   'lat': 49.262822,
#   'lon': -123.14338,
#   'capacity': 20},
#  {'station_id': '0206',
#   'name': '8th & Scotia',
#   'lat': 49.263635,
#   'lon': -123.099236,
#   'capacity': 12},
#  {'station_id': '0207',
#   'name': 'Alberni & Jervis',
#   'lat': 49.28763,
#   'lon': -123.127245,
#   'capacity': 14},
#  {'station_id': '0208',
#   'name': 'Arbutus Greenway & Broadway',
#   'lat': 49.263649,
#   'lon': -123.152421,
#   'capacity': 20},
#  {'station_id': '0209',
#   'name': 'Stanley Park - Information Booth',
#   'lat': 49.297933,
#   'lon': -123.130758,
#   'capacity': 20},
#  {'station_id': '0211',
#   'name': '14th & Alder',
#   'lat': 49.258819,
#   'lon': -123.131317,
#   'capacity': 14},
#  {'station_id': '0212',
#   'name': 'Union & Dunlevy',
#   'lat': 49.277595,
#   'lon': -123.09583,
#   'capacity': 16},
#  {'station_id': '0213',
#   'name': 'Pender & Gore',
#   'lat': 49.280284,
#   'lon': -123.097052,
#   'capacity': 14},
#  {'station_id': '0215',
#   'name': 'Princess & Union',
#   'lat': 49.277615,
#   'lon': -123.091654,
#   'capacity': 12},
#  {'station_id': '0217',
#   'name': 'Smithe & Burrard',
#   'lat': 49.283325,
#   'lon': -123.125249,
#   'capacity': 14},
#  {'station_id': '0218',
#   'name': 'Carrall & Seawall',
#   'lat': 49.276294,
#   'lon': -123.106534,
#   'capacity': 18},
#  {'station_id': '0219',
#   'name': 'Hawks & Union',
#   'lat': 49.277333,
#   'lon': -123.087359,
#   'capacity': 16},
#  {'station_id': '0221',
#   'name': 'Glen & Union',
#   'lat': 49.277469,
#   'lon': -123.081315,
#   'capacity': 14},
#  {'station_id': '0222',
#   'name': 'Adanac & McLean',
#   'lat': 49.277665,
#   'lon': -123.073653,
#   'capacity': 16},
#  {'station_id': '0223',
#   'name': 'Commercial & Adanac',
#   'lat': 49.277436,
#   'lon': -123.070427,
#   'capacity': 16},
#  {'station_id': '0224',
#   'name': 'Pender & Commercial',
#   'lat': 49.280332,
#   'lon': -123.070068,
#   'capacity': 16},
#  {'station_id': '0225',
#   'name': 'McLean & Pender',
#   'lat': 49.280205,
#   'lon': -123.074174,
#   'capacity': 16},
#  {'station_id': '0227',
#   'name': 'Campbell & Hastings',
#   'lat': 49.280852,
#   'lon': -123.084746,
#   'capacity': 16},
#  {'station_id': '0228',
#   'name': 'Keefer & Hawks',
#   'lat': 49.279235,
#   'lon': -123.087528,
#   'capacity': 16},
#  {'station_id': '0229',
#   'name': 'Keefer & Princess',
#   'lat': 49.279369,
#   'lon': -123.091241,
#   'capacity': 14},
#  {'station_id': '0230',
#   'name': 'Alexander & Railway',
#   'lat': 49.283992,
#   'lon': -123.091206,
#   'capacity': 20},
#  {'station_id': '0231',
#   'name': 'Napier & Commercial',
#   'lat': 49.274881,
#   'lon': -123.069323,
#   'capacity': 14},
#  {'station_id': '0232',
#   'name': 'Britannia Parking Lot',
#   'lat': 49.275882,
#   'lon': -123.071865,
#   'capacity': 14},
#  {'station_id': '0233',
#   'name': 'Thornton & National',
#   'lat': 49.273777,
#   'lon': -123.092723,
#   'capacity': 14},
#  {'station_id': '0234',
#   'name': 'Station & National',
#   'lat': 49.274249,
#   'lon': -123.098481,
#   'capacity': 14},
#  {'station_id': '0235',
#   'name': 'Charles & Commercial',
#   'lat': 49.273103,
#   'lon': -123.069892,
#   'capacity': 22},
#  {'station_id': '0236',
#   'name': 'Keith & 6th',
#   'lat': 49.265005,
#   'lon': -123.079481,
#   'capacity': 28},
#  {'station_id': '0237',
#   'name': 'Glen & 6th',
#   'lat': 49.265024,
#   'lon': -123.08127,
#   'capacity': 20},
#  {'station_id': '0238',
#   'name': 'Thornton & 1st',
#   'lat': 49.267553,
#   'lon': -123.094616,
#   'capacity': 26},
#  {'station_id': '0239',
#   'name': 'Grant & Commercial',
#   'lat': 49.271377,
#   'lon': -123.069416,
#   'capacity': 14},
#  {'station_id': '0240',
#   'name': '2nd & Commercial',
#   'lat': 49.268616,
#   'lon': -123.069908,
#   'capacity': 22},
#  {'station_id': '0241',
#   'name': '4th & Commercial',
#   'lat': 49.266969,
#   'lon': -123.069936,
#   'capacity': 14},
#  {'station_id': '0242',
#   'name': '8th & Commercial',
#   'lat': 49.263242,
#   'lon': -123.070521,
#   'capacity': 38},
#  {'station_id': '0244',
#   'name': '10th & Commercial',
#   'lat': 49.261403,
#   'lon': -123.070102,
#   'capacity': 26},
#  {'station_id': '0245',
#   'name': 'Woodland & 10th',
#   'lat': 49.261263,
#   'lon': -123.073707,
#   'capacity': 14},
#  {'station_id': '0246',
#   'name': 'Glen & Broadway',
#   'lat': 49.262242,
#   'lon': -123.081459,
#   'capacity': 18},
#  {'station_id': '0248',
#   'name': 'St George & Broadway',
#   'lat': 49.262321,
#   'lon': -123.09306,
#   'capacity': 14},
#  {'station_id': '0249',
#   'name': '7th & Woodland',
#   'lat': 49.264251,
#   'lon': -123.073853,
#   'capacity': 12},
#  {'station_id': '0250',
#   'name': 'Woodland & 4th',
#   'lat': 49.266751,
#   'lon': -123.073501,
#   'capacity': 14},
#  {'station_id': '0252',
#   'name': 'Woodland & Graveley',
#   'lat': 49.270684,
#   'lon': -123.073562,
#   'capacity': 12},
#  {'station_id': '0253',
#   'name': 'Charles & Woodland',
#   'lat': 49.2731,
#   'lon': -123.0732,
#   'capacity': 14},
#  {'station_id': '0254',
#   'name': 'Grandview Bike Lane & Commercial',
#   'lat': 49.264083,
#   'lon': -123.070611,
#   'capacity': 42},
#  {'station_id': '0255',
#   'name': '18th & Main',
#   'lat': 49.254667,
#   'lon': -123.101389,
#   'capacity': 16},
#  {'station_id': '0256',
#   'name': 'Prince Edward & 16th',
#   'lat': 49.256694,
#   'lon': -123.096579,
#   'capacity': 14},
#  {'station_id': '0257',
#   'name': 'Prince Edward & 14th',
#   'lat': 49.258352,
#   'lon': -123.096337,
#   'capacity': 14},
#  {'station_id': '0258',
#   'name': '13th & St George',
#   'lat': 49.258817,
#   'lon': -123.092797,
#   'capacity': 16},
#  {'station_id': '0260',
#   'name': '10th & Fraser',
#   'lat': 49.26151,
#   'lon': -123.089413,
#   'capacity': 14},
#  {'station_id': '0261',
#   'name': '8th & Fraser',
#   'lat': 49.263382,
#   'lon': -123.088837,
#   'capacity': 16},
#  {'station_id': '0262',
#   'name': '8th & Prince Edward',
#   'lat': 49.263518,
#   'lon': -123.09568,
#   'capacity': 18},
#  {'station_id': '0265',
#   'name': 'St Catherines & 10th',
#   'lat': 49.261353,
#   'lon': -123.085333,
#   'capacity': 12},
#  {'station_id': '0266',
#   'name': 'St Catherines & 7th',
#   'lat': 49.264466,
#   'lon': -123.085183,
#   'capacity': 20},
#  {'station_id': '0272',
#   'name': 'Pender & Victoria',
#   'lat': 49.280197,
#   'lon': -123.065859,
#   'capacity': 16},
#  {'station_id': '0273',
#   'name': 'Victoria & 4th',
#   'lat': 49.266725,
#   'lon': -123.065925,
#   'capacity': 16},
#  {'station_id': '0274',
#   'name': 'Victoria & 10th',
#   'lat': 49.261188,
#   'lon': -123.066009,
#   'capacity': 12},
#  {'station_id': '0278',
#   'name': '15th & Victoria (Trout Lake)',
#   'lat': 49.256857,
#   'lon': -123.065646,
#   'capacity': 18},
#  {'station_id': '0280',
#   'name': 'Triumph & Victoria',
#   'lat': 49.283986,
#   'lon': -123.065264,
#   'capacity': 16},
#  {'station_id': '0281',
#   'name': 'Windsor & 14th',
#   'lat': 49.257985,
#   'lon': -123.083366,
#   'capacity': 14},
#  {'station_id': '0282',
#   'name': '14th & Fraser',
#   'lat': 49.257939,
#   'lon': -123.089531,
#   'capacity': 16},
#  {'station_id': '0283',
#   'name': '15th & Knight',
#   'lat': 49.256496,
#   'lon': -123.075426,
#   'capacity': 14},
#  {'station_id': '0285',
#   'name': 'Commercial & Pandora',
#   'lat': 49.283236,
#   'lon': -123.070443,
#   'capacity': 16},
#  {'station_id': '0287',
#   'name': 'Carolina & Great Northern Way',
#   'lat': 49.267266,
#   'lon': -123.090786,
#   'capacity': 16},
#  {'station_id': '0297',
#   'name': '6th & Prince Edward',
#   'lat': 49.265242,
#   'lon': -123.095577,
#   'capacity': 16},
#  {'station_id': '0298',
#   'name': '6th & Carolina',
#   'lat': 49.265213,
#   'lon': -123.090785,
#   'capacity': 16},
#  {'station_id': '0300',
#   'name': 'Bute & Barclay',
#   'lat': 49.284893,
#   'lon': -123.128685,
#   'capacity': 14}]

# %%
# Lists to hold response data 
station_id = []
name = []
lat = []
lon = []

# loop and make requests and parse
for i in stations:
#target_url = url + stations
#response = requests.get(target_url).json()
    station_id.append(i["station_id"])
    name.append(i["name"])
    lat.append(i["lat"])
    lon.append(i["lon"])

# %%
# build a dataframe
station_info = pd.DataFrame({
    "station_id": station_id,
    "name": station_name,
    "lat": latitude,
    "lon": longitude})
station_info

# %%
station_id
# Out:
# ['0001',
#  '0002',
#  '0004',
#  '0005',
#  '0006',
#  '0007',
#  '0008',
#  '0009',
#  '0010',
#  '0011',
#  '0012',
#  '0014',
#  '0015',
#  '0016',
#  '0017',
#  '0019',
#  '0021',
#  '0024',
#  '0025',
#  '0026',
#  '0027',
#  '0028',
#  '0030',
#  '0031',
#  '0032',
#  '0033',
#  '0034',
#  '0035',
#  '0036',
#  '0037',
#  '0039',
#  '0040',
#  '0041',
#  '0044',
#  '0045',
#  '0047',
#  '0048',
#  '0050',
#  '0052',
#  '0053',
#  '0054',
#  '0055',
#  '0057',
#  '0058',
#  '0060',
#  '0063',
#  '0064',
#  '0065',
#  '0066',
#  '0068',
#  '0069',
#  '0070',
#  '0071',
#  '0072',
#  '0073',
#  '0074',
#  '0076',
#  '0077',
#  '0078',
#  '0079',
#  '0080',
#  '0081',
#  '0082',
#  '0083',
#  '0084',
#  '0087',
#  '0088',
#  '0089',
#  '0092',
#  '0093',
#  '0096',
#  '0098',
#  '0099',
#  '0101',
#  '0102',
#  '0103',
#  '0104',
#  '0105',
#  '0106',
#  '0107',
#  '0108',
#  '0109',
#  '0110',
#  '0112',
#  '0113',
#  '0114',
#  '0115',
#  '0119',
#  '0123',
#  '0124',
#  '0125',
#  '0126',
#  '0129',
#  '0130',
#  '0132',
#  '0133',
#  '0134',
#  '0136',
#  '0137',
#  '0138',
#  '0139',
#  '0140',
#  '0143',
#  '0147',
#  '0148',
#  '0150',
#  '0152',
#  '0153',
#  '0154',
#  '0155',
#  '0159',
#  '0161',
#  '0165',
#  '0166',
#  '0167',
#  '0170',
#  '0171',
#  '0172',
#  '0173',
#  '0174',
#  '0176',
#  '0177',
#  '0179',
#  '0180',
#  '0186',
#  '0187',
#  '0190',
#  '0191',
#  '0192',
#  '0193',
#  '0196',
#  '0197',
#  '0198',
#  '0199',
#  '0201',
#  '0202',
#  '0203',
#  '0204',
#  '0205',
#  '0206',
#  '0207',
#  '0208',
#  '0209',
#  '0211',
#  '0212',
#  '0213',
#  '0215',
#  '0217',
#  '0218',
#  '0219',
#  '0221',
#  '0222',
#  '0223',
#  '0224',
#  '0225',
#  '0227',
#  '0228',
#  '0229',
#  '0230',
#  '0231',
#  '0232',
#  '0233',
#  '0234',
#  '0235',
#  '0236',
#  '0237',
#  '0238',
#  '0239',
#  '0240',
#  '0241',
#  '0242',
#  '0244',
#  '0245',
#  '0246',
#  '0248',
#  '0249',
#  '0250',
#  '0252',
#  '0253',
#  '0254',
#  '0255',
#  '0256',
#  '0257',
#  '0258',
#  '0260',
#  '0261',
#  '0262',
#  '0265',
#  '0266',
#  '0272',
#  '0273',
#  '0274',
#  '0278',
#  '0280',
#  '0281',
#  '0282',
#  '0283',
#  '0285',
#  '0287',
#  '0297',
#  '0298',
#  '0300']
