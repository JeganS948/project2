# %% [markdown]
# # Import dependencies

# %%
import os 
import csv
import pandas as pd
import requests
import datetime as dt

# %% [markdown]
# # Data Files

# %%
vancouver_01_path = os.path.join("Resources","Mobi_System_Data_2019-01.csv")
vancouver_02_path = os.path.join("Resources","Mobi_System_Data_2019-02.csv")
vancouver_03_path = os.path.join("Resources","Mobi_System_Data_2019-03.csv")
vancouver_04_path = os.path.join("Resources","Mobi_System_Data_2019-04.csv")
vancouver_05_path = os.path.join("Resources","Mobi_System_Data_2019-05.csv")
vancouver_06_path = os.path.join("Resources","Mobi_System_Data_2019-06.csv")
vancouver_07_path = os.path.join("Resources","Mobi_System_Data_2019-07.csv")
vancouver_08_path = os.path.join("Resources","Mobi_System_Data_2019-08.csv")
vancouver_09_path = os.path.join("Resources","Mobi_System_Data_2019-09.csv")
vancouver_10_path = os.path.join("Resources","Mobi_System_Data_2019-10.csv")
vancouver_11_path = os.path.join("Resources","Mobi_System_Data_2019-11.csv")
vancouver_12_path = os.path.join("Resources","Mobi_System_Data_2019-12.csv")

# %% [markdown]
# # Read Data Files

# %%
vancouver_01 = pd.read_csv(vancouver_01_path, encoding="utf=8")
vancouver_02 = pd.read_csv(vancouver_02_path, encoding="utf=8")
vancouver_03 = pd.read_csv(vancouver_03_path, encoding="utf=8")
vancouver_04 = pd.read_csv(vancouver_04_path, encoding="utf=8")
vancouver_05 = pd.read_csv(vancouver_05_path, encoding="utf=8")
vancouver_06 = pd.read_csv(vancouver_06_path, encoding="utf=8")
vancouver_07 = pd.read_csv(vancouver_07_path, encoding="utf=8")
vancouver_08 = pd.read_csv(vancouver_08_path, encoding="utf=8")
vancouver_09 = pd.read_csv(vancouver_09_path, encoding="utf=8")
vancouver_10 = pd.read_csv(vancouver_10_path, encoding="utf=8")
vancouver_11 = pd.read_csv(vancouver_11_path, encoding="utf=8")
vancouver_12 = pd.read_csv(vancouver_12_path, encoding="utf=8")

# %%
vancouver_01
# Out:
#              Departure         Return    Bike  \
# 0        2/1/2019 0:00  2/1/2019 0:00   388.0
# 1        2/1/2019 0:00  2/1/2019 0:00  1880.0
# 2        2/1/2019 0:00  2/1/2019 0:00   779.0
# 3        2/1/2019 0:00  2/1/2019 0:00  2123.0
# 4      1/31/2019 23:00  2/1/2019 0:00   444.0
# ...                ...            ...     ...
# 36745    1/1/2019 0:00  1/1/2019 1:00   511.0
# 36746    1/1/2019 0:00  1/1/2019 0:00   723.0
# 36747    1/1/2019 0:00  1/1/2019 1:00   938.0
# 36748    1/1/2019 0:00  1/1/2019 0:00  1450.0
# 36749    1/1/2019 0:00  1/1/2019 1:00   161.0
#
#                      Departure station                  Return station  \
# 0                      0198 6th & Main             0298 6th & Carolina
# 1                   0193 Science World             0173 1st & Columbia
# 2              0063 Robson & Granville  0143 South False Creek Seawall
# 3                   0064 Expo & Smithe          0078 Nelson & Mainland
# 4               0060 Bidwell & Burnaby             0196 Drake & Hornby
# ...                                ...                             ...
# 36745  0105 Stanley Park - Totem Poles          0084 Sunset Beach West
# 36746              0088 Harwood & Bute          0218 Carrall & Seawall
# 36747               0139 Burrard & 4th         0167 Cordova & Columbia
# 36748              0088 Harwood & Bute          0218 Carrall & Seawall
# 36749          0098 Carrall & Hastings        0012 Dunsmuir & Richards
#
#               Membership type  Covered distance (m)  Duration (sec.)  \
# 0                365 Standard                 714.0              177
# 1                    365 Plus                 859.0              221
# 2      Vancity Community Pass                6691.0             3272
# 3      365 Day Pass Plus SALE                 473.0              157
# 4      365 Day Pass Plus SALE                1404.0              516
# ...                       ...                   ...              ...
# 36745                 24 Hour                4569.0             1382
# 36746  365 Corporate Standard                3689.0             1009
# 36747   365 Day Founding Plus                4737.0             1144
# 36748   365 Day Founding Plus                3702.0             1105
# 36749                 24 Hour                1686.0             1300
#
#        Departure battery voltage (mV)  Return battery voltage (mV)  \
# 0                                3826                         4000
# 1                                3705                         3850
# 2                                3842                         4059
# 3                                4029                         4140
# 4                                3990                         4100
# ...                               ...                          ...
# 36745                            4076                         4214
# 36746                            3750                         3969
# 36747                            3589                         3848
# 36748                            3568                         3876
# 36749                            3823                         3964
#
#        Departure temperature (C)  Return temperature (C)  Stopover duration  \
# 0                              9                       9                  0
# 1                              9                      11                  0
# 2                             10                      11                370
# 3                              9                      10                  0
# 4                              9                      10                  0
# ...                          ...                     ...                ...
# 36745                          4                       6                  0
# 36746                          5                       7                  0
# 36747                          5                       8                  0
# 36748                          5                       6                  0
# 36749                          5                       5                  0
#
#        Number of stopovers Manager
# 0                        0   False
# 1                        0   False
# 2                        1   False
# 3                        0   False
# 4                        0   False
# ...                    ...     ...
# 36745                    0   False
# 36746                    0   False
# 36747                    0   False
# 36748                    0   False
# 36749                    0   False
#
# [36750 rows x 15 columns]

# %%
# # drop columns
columns=["Departure", "Return", "Bike", "Departure station", "Return station", "Membership type", "Duration (sec.)"]
vancouver_01 = vancouver_01[columns]
vancouver_02= vancouver_02.rename(columns={"Membership Type": "Membership type"})
vancouver_02 = vancouver_02[columns]
vancouver_03 = vancouver_03[columns]
vancouver_04 = vancouver_04[columns]
vancouver_05 = vancouver_05[columns]
vancouver_06 = vancouver_06[columns]
vancouver_07 = vancouver_07[columns]
vancouver_08 = vancouver_08[columns]
vancouver_09 = vancouver_09[columns]
vancouver_10 = vancouver_10[columns]
vancouver_11 = vancouver_11[columns]
vancouver_12= vancouver_12.rename(columns={"Membership Type": "Membership type"})
vancouver_12 = vancouver_12[columns]

# %%
vancouver_01
# Out:
#              Departure         Return    Bike  \
# 0        2/1/2019 0:00  2/1/2019 0:00   388.0
# 1        2/1/2019 0:00  2/1/2019 0:00  1880.0
# 2        2/1/2019 0:00  2/1/2019 0:00   779.0
# 3        2/1/2019 0:00  2/1/2019 0:00  2123.0
# 4      1/31/2019 23:00  2/1/2019 0:00   444.0
# ...                ...            ...     ...
# 36745    1/1/2019 0:00  1/1/2019 1:00   511.0
# 36746    1/1/2019 0:00  1/1/2019 0:00   723.0
# 36747    1/1/2019 0:00  1/1/2019 1:00   938.0
# 36748    1/1/2019 0:00  1/1/2019 0:00  1450.0
# 36749    1/1/2019 0:00  1/1/2019 1:00   161.0
#
#                      Departure station                  Return station  \
# 0                      0198 6th & Main             0298 6th & Carolina
# 1                   0193 Science World             0173 1st & Columbia
# 2              0063 Robson & Granville  0143 South False Creek Seawall
# 3                   0064 Expo & Smithe          0078 Nelson & Mainland
# 4               0060 Bidwell & Burnaby             0196 Drake & Hornby
# ...                                ...                             ...
# 36745  0105 Stanley Park - Totem Poles          0084 Sunset Beach West
# 36746              0088 Harwood & Bute          0218 Carrall & Seawall
# 36747               0139 Burrard & 4th         0167 Cordova & Columbia
# 36748              0088 Harwood & Bute          0218 Carrall & Seawall
# 36749          0098 Carrall & Hastings        0012 Dunsmuir & Richards
#
#               Membership type  Duration (sec.)
# 0                365 Standard              177
# 1                    365 Plus              221
# 2      Vancity Community Pass             3272
# 3      365 Day Pass Plus SALE              157
# 4      365 Day Pass Plus SALE              516
# ...                       ...              ...
# 36745                 24 Hour             1382
# 36746  365 Corporate Standard             1009
# 36747   365 Day Founding Plus             1144
# 36748   365 Day Founding Plus             1105
# 36749                 24 Hour             1300
#
# [36750 rows x 7 columns]

# %%
#Add new column:location_id
vancouver_01["location_id"]=2
vancouver_02["location_id"]=2
vancouver_03["location_id"]=2
vancouver_04["location_id"]=2
vancouver_05["location_id"]=2
vancouver_06["location_id"]=2
vancouver_07["location_id"]=2
vancouver_08["location_id"]=2
vancouver_09["location_id"]=2
vancouver_10["location_id"]=2
vancouver_11["location_id"]=2
vancouver_12["location_id"]=2
# Out:
# <ipython-input-253-4ba426c46331>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vancouver_01["location_id"]=2

# %%
vancouver_01
# Out:
#              Departure         Return    Bike  \
# 0        2/1/2019 0:00  2/1/2019 0:00   388.0
# 1        2/1/2019 0:00  2/1/2019 0:00  1880.0
# 2        2/1/2019 0:00  2/1/2019 0:00   779.0
# 3        2/1/2019 0:00  2/1/2019 0:00  2123.0
# 4      1/31/2019 23:00  2/1/2019 0:00   444.0
# ...                ...            ...     ...
# 36745    1/1/2019 0:00  1/1/2019 1:00   511.0
# 36746    1/1/2019 0:00  1/1/2019 0:00   723.0
# 36747    1/1/2019 0:00  1/1/2019 1:00   938.0
# 36748    1/1/2019 0:00  1/1/2019 0:00  1450.0
# 36749    1/1/2019 0:00  1/1/2019 1:00   161.0
#
#                      Departure station                  Return station  \
# 0                      0198 6th & Main             0298 6th & Carolina
# 1                   0193 Science World             0173 1st & Columbia
# 2              0063 Robson & Granville  0143 South False Creek Seawall
# 3                   0064 Expo & Smithe          0078 Nelson & Mainland
# 4               0060 Bidwell & Burnaby             0196 Drake & Hornby
# ...                                ...                             ...
# 36745  0105 Stanley Park - Totem Poles          0084 Sunset Beach West
# 36746              0088 Harwood & Bute          0218 Carrall & Seawall
# 36747               0139 Burrard & 4th         0167 Cordova & Columbia
# 36748              0088 Harwood & Bute          0218 Carrall & Seawall
# 36749          0098 Carrall & Hastings        0012 Dunsmuir & Richards
#
#               Membership type  Duration (sec.)  location_id
# 0                365 Standard              177            2
# 1                    365 Plus              221            2
# 2      Vancity Community Pass             3272            2
# 3      365 Day Pass Plus SALE              157            2
# 4      365 Day Pass Plus SALE              516            2
# ...                       ...              ...          ...
# 36745                 24 Hour             1382            2
# 36746  365 Corporate Standard             1009            2
# 36747   365 Day Founding Plus             1144            2
# 36748   365 Day Founding Plus             1105            2
# 36749                 24 Hour             1300            2
#
# [36750 rows x 8 columns]

# %%
#performing concatenation
vancouver = [vancouver_01,vancouver_02,vancouver_03,vancouver_04,vancouver_05,vancouver_06,
             vancouver_07,vancouver_08,vancouver_09,vancouver_10,vancouver_11,vancouver_12]
bike_share = pd.concat(vancouver).drop_duplicates().reset_index(drop=True)
bike_share
# Out:
#               Departure           Return    Bike  \
# 0         2/1/2019 0:00    2/1/2019 0:00   388.0
# 1         2/1/2019 0:00    2/1/2019 0:00  1880.0
# 2         2/1/2019 0:00    2/1/2019 0:00   779.0
# 3         2/1/2019 0:00    2/1/2019 0:00  2123.0
# 4       1/31/2019 23:00    2/1/2019 0:00   444.0
# ...                 ...              ...     ...
# 891714  2019-12-01 0:00  2019-12-01 0:00   631.0
# 891715  2019-12-01 0:00  2019-12-01 1:00  1394.0
# 891716  2019-12-01 0:00  2019-12-01 0:00  1511.0
# 891717  2019-12-01 0:00  2019-12-01 0:00   985.0
# 891718  2019-12-01 0:00  2019-12-01 0:00   291.0
#
#                                Departure station  \
# 0                                0198 6th & Main
# 1                             0193 Science World
# 2                        0063 Robson & Granville
# 3                             0064 Expo & Smithe
# 4                         0060 Bidwell & Burnaby
# ...                                          ...
# 891714                         0187 Bute & Davie
# 891715                      0024 Hornby & Pender
# 891716  0099 Vancouver Art Gallery - North Plaza
# 891717                        0193 Science World
# 891718                        0193 Science World
#
#                           Return station            Membership type  \
# 0                    0298 6th & Carolina               365 Standard
# 1                    0173 1st & Columbia                   365 Plus
# 2         0143 South False Creek Seawall     Vancity Community Pass
# 3                 0078 Nelson & Mainland     365 Day Pass Plus SALE
# 4                    0196 Drake & Hornby     365 Day Pass Plus SALE
# ...                                  ...                        ...
# 891714               0032 Comox & Denman                30 Day Pass
# 891715  0208 Arbutus Greenway & Broadway               365 Standard
# 891716              0096 Nicola & Robson  365 Day Founding Standard
# 891717               0174 1st & Manitoba                   365 Plus
# 891718               0174 1st & Manitoba                   365 Plus
#
#         Duration (sec.)  location_id
# 0                   177            2
# 1                   221            2
# 2                  3272            2
# 3                   157            2
# 4                   516            2
# ...                 ...          ...
# 891714              327            2
# 891715             1473            2
# 891716              358            2
# 891717              163            2
# 891718              167            2
#
# [891719 rows x 8 columns]

# %%
# remove rows with null values
bike_share = bike_share.dropna()

# %%
bike_share
# Out:
#               Departure           Return    Bike  \
# 0         2/1/2019 0:00    2/1/2019 0:00   388.0
# 1         2/1/2019 0:00    2/1/2019 0:00  1880.0
# 2         2/1/2019 0:00    2/1/2019 0:00   779.0
# 3         2/1/2019 0:00    2/1/2019 0:00  2123.0
# 4       1/31/2019 23:00    2/1/2019 0:00   444.0
# ...                 ...              ...     ...
# 891714  2019-12-01 0:00  2019-12-01 0:00   631.0
# 891715  2019-12-01 0:00  2019-12-01 1:00  1394.0
# 891716  2019-12-01 0:00  2019-12-01 0:00  1511.0
# 891717  2019-12-01 0:00  2019-12-01 0:00   985.0
# 891718  2019-12-01 0:00  2019-12-01 0:00   291.0
#
#                                Departure station  \
# 0                                0198 6th & Main
# 1                             0193 Science World
# 2                        0063 Robson & Granville
# 3                             0064 Expo & Smithe
# 4                         0060 Bidwell & Burnaby
# ...                                          ...
# 891714                         0187 Bute & Davie
# 891715                      0024 Hornby & Pender
# 891716  0099 Vancouver Art Gallery - North Plaza
# 891717                        0193 Science World
# 891718                        0193 Science World
#
#                           Return station            Membership type  \
# 0                    0298 6th & Carolina               365 Standard
# 1                    0173 1st & Columbia                   365 Plus
# 2         0143 South False Creek Seawall     Vancity Community Pass
# 3                 0078 Nelson & Mainland     365 Day Pass Plus SALE
# 4                    0196 Drake & Hornby     365 Day Pass Plus SALE
# ...                                  ...                        ...
# 891714               0032 Comox & Denman                30 Day Pass
# 891715  0208 Arbutus Greenway & Broadway               365 Standard
# 891716              0096 Nicola & Robson  365 Day Founding Standard
# 891717               0174 1st & Manitoba                   365 Plus
# 891718               0174 1st & Manitoba                   365 Plus
#
#         Duration (sec.)  location_id
# 0                   177            2
# 1                   221            2
# 2                  3272            2
# 3                   157            2
# 4                   516            2
# ...                 ...          ...
# 891714              327            2
# 891715             1473            2
# 891716              358            2
# 891717              163            2
# 891718              167            2
#
# [891010 rows x 8 columns]

# %%
#Renaming columns
bike_share = bike_share.rename(columns={"Bike": "bike_id",
                                        "Departure station":"start station id",
                                        "Return station":"end station id",
                                        "Departure":"starttime",
                                        "Return":"stoptime",
                                        "Duration (sec.)":"tripduration",
                                        "Membership type":"usertype"})

bike_share
# Out:
#               starttime         stoptime  bike_id  \
# 0         2/1/2019 0:00    2/1/2019 0:00    388.0
# 1         2/1/2019 0:00    2/1/2019 0:00   1880.0
# 2         2/1/2019 0:00    2/1/2019 0:00    779.0
# 3         2/1/2019 0:00    2/1/2019 0:00   2123.0
# 4       1/31/2019 23:00    2/1/2019 0:00    444.0
# ...                 ...              ...      ...
# 891714  2019-12-01 0:00  2019-12-01 0:00    631.0
# 891715  2019-12-01 0:00  2019-12-01 1:00   1394.0
# 891716  2019-12-01 0:00  2019-12-01 0:00   1511.0
# 891717  2019-12-01 0:00  2019-12-01 0:00    985.0
# 891718  2019-12-01 0:00  2019-12-01 0:00    291.0
#
#                                 start station id  \
# 0                                0198 6th & Main
# 1                             0193 Science World
# 2                        0063 Robson & Granville
# 3                             0064 Expo & Smithe
# 4                         0060 Bidwell & Burnaby
# ...                                          ...
# 891714                         0187 Bute & Davie
# 891715                      0024 Hornby & Pender
# 891716  0099 Vancouver Art Gallery - North Plaza
# 891717                        0193 Science World
# 891718                        0193 Science World
#
#                           end station id                   usertype  \
# 0                    0298 6th & Carolina               365 Standard
# 1                    0173 1st & Columbia                   365 Plus
# 2         0143 South False Creek Seawall     Vancity Community Pass
# 3                 0078 Nelson & Mainland     365 Day Pass Plus SALE
# 4                    0196 Drake & Hornby     365 Day Pass Plus SALE
# ...                                  ...                        ...
# 891714               0032 Comox & Denman                30 Day Pass
# 891715  0208 Arbutus Greenway & Broadway               365 Standard
# 891716              0096 Nicola & Robson  365 Day Founding Standard
# 891717               0174 1st & Manitoba                   365 Plus
# 891718               0174 1st & Manitoba                   365 Plus
#
#         tripduration  location_id
# 0                177            2
# 1                221            2
# 2               3272            2
# 3                157            2
# 4                516            2
# ...              ...          ...
# 891714           327            2
# 891715          1473            2
# 891716           358            2
# 891717           163            2
# 891718           167            2
#
# [891010 rows x 8 columns]

# %%
#total count of list
bike_share.count()
# Out:
# starttime           891010
# stoptime            891010
# bike_id             891010
# start station id    891010
# end station id      891010
# usertype            891010
# tripduration        891010
# location_id         891010
# dtype: int64

# %%
#Bike ID
bikes = pd.DataFrame(bike_share[["bike_id","location_id"]])
bikes = bikes.drop_duplicates().reset_index(drop=True)

# %%
bikes
# Out:
#       bike_id  location_id
# 0       388.0            2
# 1      1880.0            2
# 2       779.0            2
# 3      2123.0            2
# 4       444.0            2
# ...       ...          ...
# 2006   1805.0            2
# 2007    638.0            2
# 2008   1853.0            2
# 2009   1819.0            2
# 2010   1750.0            2
#
# [2011 rows x 2 columns]

# %%
#drop bad dates
bike_share= bike_share.loc[(bike_share["stoptime"]!= "1900-01-00 0:00")]
bike_share
# Out:
#               starttime         stoptime  bike_id  \
# 0         2/1/2019 0:00    2/1/2019 0:00    388.0
# 1         2/1/2019 0:00    2/1/2019 0:00   1880.0
# 2         2/1/2019 0:00    2/1/2019 0:00    779.0
# 3         2/1/2019 0:00    2/1/2019 0:00   2123.0
# 4       1/31/2019 23:00    2/1/2019 0:00    444.0
# ...                 ...              ...      ...
# 891714  2019-12-01 0:00  2019-12-01 0:00    631.0
# 891715  2019-12-01 0:00  2019-12-01 1:00   1394.0
# 891716  2019-12-01 0:00  2019-12-01 0:00   1511.0
# 891717  2019-12-01 0:00  2019-12-01 0:00    985.0
# 891718  2019-12-01 0:00  2019-12-01 0:00    291.0
#
#                                 start station id  \
# 0                                0198 6th & Main
# 1                             0193 Science World
# 2                        0063 Robson & Granville
# 3                             0064 Expo & Smithe
# 4                         0060 Bidwell & Burnaby
# ...                                          ...
# 891714                         0187 Bute & Davie
# 891715                      0024 Hornby & Pender
# 891716  0099 Vancouver Art Gallery - North Plaza
# 891717                        0193 Science World
# 891718                        0193 Science World
#
#                           end station id                   usertype  \
# 0                    0298 6th & Carolina               365 Standard
# 1                    0173 1st & Columbia                   365 Plus
# 2         0143 South False Creek Seawall     Vancity Community Pass
# 3                 0078 Nelson & Mainland     365 Day Pass Plus SALE
# 4                    0196 Drake & Hornby     365 Day Pass Plus SALE
# ...                                  ...                        ...
# 891714               0032 Comox & Denman                30 Day Pass
# 891715  0208 Arbutus Greenway & Broadway               365 Standard
# 891716              0096 Nicola & Robson  365 Day Founding Standard
# 891717               0174 1st & Manitoba                   365 Plus
# 891718               0174 1st & Manitoba                   365 Plus
#
#         tripduration  location_id
# 0                177            2
# 1                221            2
# 2               3272            2
# 3                157            2
# 4                516            2
# ...              ...          ...
# 891714           327            2
# 891715          1473            2
# 891716           358            2
# 891717           163            2
# 891718           167            2
#
# [891010 rows x 8 columns]

# %%
# Display Data Table for Preview
bike_share["Member Type"]=bike_share["Membership type"]
bike_share
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Membership type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-fb376b84c90b> in <module>
#       1 # Display Data Table for Preview
# ----> 2 bike_share["Member Type"]=bike_share["Membership type"]
#       3 bike_share
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Membership type'

# %%
# drop columns
i =["Member Type"]
bike_share=bike_share.drop(columns=i)

# %%
bike_share
# Out:
#               Departure           Return  Bike_id  \
# 0         2/1/2019 0:00    2/1/2019 0:00    388.0
# 1         2/1/2019 0:00    2/1/2019 0:00   1880.0
# 2         2/1/2019 0:00    2/1/2019 0:00    779.0
# 3         2/1/2019 0:00    2/1/2019 0:00   2123.0
# 4       1/31/2019 23:00    2/1/2019 0:00    444.0
# ...                 ...              ...      ...
# 891714  2019-12-01 0:00  2019-12-01 0:00    631.0
# 891715  2019-12-01 0:00  2019-12-01 1:00   1394.0
# 891716  2019-12-01 0:00  2019-12-01 0:00   1511.0
# 891717  2019-12-01 0:00  2019-12-01 0:00    985.0
# 891718  2019-12-01 0:00  2019-12-01 0:00    291.0
#
#                                 start station id  \
# 0                                0198 6th & Main
# 1                             0193 Science World
# 2                        0063 Robson & Granville
# 3                             0064 Expo & Smithe
# 4                         0060 Bidwell & Burnaby
# ...                                          ...
# 891714                         0187 Bute & Davie
# 891715                      0024 Hornby & Pender
# 891716  0099 Vancouver Art Gallery - North Plaza
# 891717                        0193 Science World
# 891718                        0193 Science World
#
#                           end station id            Membership type  \
# 0                    0298 6th & Carolina               365 Standard
# 1                    0173 1st & Columbia                   365 Plus
# 2         0143 South False Creek Seawall     Vancity Community Pass
# 3                 0078 Nelson & Mainland     365 Day Pass Plus SALE
# 4                    0196 Drake & Hornby     365 Day Pass Plus SALE
# ...                                  ...                        ...
# 891714               0032 Comox & Denman                30 Day Pass
# 891715  0208 Arbutus Greenway & Broadway               365 Standard
# 891716              0096 Nicola & Robson  365 Day Founding Standard
# 891717               0174 1st & Manitoba                   365 Plus
# 891718               0174 1st & Manitoba                   365 Plus
#
#         Duration (sec.)  location_id
# 0                   177            2
# 1                   221            2
# 2                  3272            2
# 3                   157            2
# 4                   516            2
# ...                 ...          ...
# 891714              327            2
# 891715             1473            2
# 891716              358            2
# 891717              163            2
# 891718              167            2
#
# [891010 rows x 8 columns]

# %%
#Membership :User type
usertype = pd.DataFrame(bike_share[["Membership type","location_id"]])
usertype = usertype.drop_duplicates().reset_index(drop=True)
usertype
# Out:
#                    Membership type  location_id
# 0                     365 Standard            2
# 1                         365 Plus            2
# 2           Vancity Community Pass            2
# 3           365 Day Pass Plus SALE            2
# 4        365 Day Founding Standard            2
# 5       365 Day Pass Standard SALE            2
# 6           365 Corporate Standard            2
# 7                           90 Day            2
# 8               365 Corporate Plus            2
# 9            365 Day Founding Plus            2
# 10           Archived Monthly Plus            2
# 11          Archived Monthly Basic            2
# 12  365 Corporate Standard Renewal            2
# 13       Archived Monthly Standard            2
# 14      365 Corporate Plus Renewal            2
# 15                         24 Hour            2
# 16                             VIP            2
# 17                     30 Day Pass            2
# 18                Single Trip Pass            2
# 19            Shared Mobility Pass            2
# 20                 Archived 90 Day            2

# %%
#Getting Departure station id
bike_share["start station id"]= bike_share["start station id"].str.split(" ", n = 1, expand = True)

# %%
bike_share
# Out:
#               Departure           Return  Bike_id start station id  \
# 0         2/1/2019 0:00    2/1/2019 0:00    388.0             0198
# 1         2/1/2019 0:00    2/1/2019 0:00   1880.0             0193
# 2         2/1/2019 0:00    2/1/2019 0:00    779.0             0063
# 3         2/1/2019 0:00    2/1/2019 0:00   2123.0             0064
# 4       1/31/2019 23:00    2/1/2019 0:00    444.0             0060
# ...                 ...              ...      ...              ...
# 891714  2019-12-01 0:00  2019-12-01 0:00    631.0             0187
# 891715  2019-12-01 0:00  2019-12-01 1:00   1394.0             0024
# 891716  2019-12-01 0:00  2019-12-01 0:00   1511.0             0099
# 891717  2019-12-01 0:00  2019-12-01 0:00    985.0             0193
# 891718  2019-12-01 0:00  2019-12-01 0:00    291.0             0193
#
#                           end station id            Membership type  \
# 0                    0298 6th & Carolina               365 Standard
# 1                    0173 1st & Columbia                   365 Plus
# 2         0143 South False Creek Seawall     Vancity Community Pass
# 3                 0078 Nelson & Mainland     365 Day Pass Plus SALE
# 4                    0196 Drake & Hornby     365 Day Pass Plus SALE
# ...                                  ...                        ...
# 891714               0032 Comox & Denman                30 Day Pass
# 891715  0208 Arbutus Greenway & Broadway               365 Standard
# 891716              0096 Nicola & Robson  365 Day Founding Standard
# 891717               0174 1st & Manitoba                   365 Plus
# 891718               0174 1st & Manitoba                   365 Plus
#
#         Duration (sec.)  location_id
# 0                   177            2
# 1                   221            2
# 2                  3272            2
# 3                   157            2
# 4                   516            2
# ...                 ...          ...
# 891714              327            2
# 891715             1473            2
# 891716              358            2
# 891717              163            2
# 891718              167            2
#
# [891010 rows x 8 columns]

# %%
# Getting Return station id
bike_share["end station id"]= bike_share["end station id"].str.split(" ", n = 1, expand = True)

# %%
bike_share
# Out:
#               Departure           Return  Bike_id start station id  \
# 0         2/1/2019 0:00    2/1/2019 0:00    388.0             0198
# 1         2/1/2019 0:00    2/1/2019 0:00   1880.0             0193
# 2         2/1/2019 0:00    2/1/2019 0:00    779.0             0063
# 3         2/1/2019 0:00    2/1/2019 0:00   2123.0             0064
# 4       1/31/2019 23:00    2/1/2019 0:00    444.0             0060
# ...                 ...              ...      ...              ...
# 891714  2019-12-01 0:00  2019-12-01 0:00    631.0             0187
# 891715  2019-12-01 0:00  2019-12-01 1:00   1394.0             0024
# 891716  2019-12-01 0:00  2019-12-01 0:00   1511.0             0099
# 891717  2019-12-01 0:00  2019-12-01 0:00    985.0             0193
# 891718  2019-12-01 0:00  2019-12-01 0:00    291.0             0193
#
#        end station id            Membership type  Duration (sec.)  location_id
# 0                0298               365 Standard              177            2
# 1                0173                   365 Plus              221            2
# 2                0143     Vancity Community Pass             3272            2
# 3                0078     365 Day Pass Plus SALE              157            2
# 4                0196     365 Day Pass Plus SALE              516            2
# ...               ...                        ...              ...          ...
# 891714           0032                30 Day Pass              327            2
# 891715           0208               365 Standard             1473            2
# 891716           0096  365 Day Founding Standard              358            2
# 891717           0174                   365 Plus              163            2
# 891718           0174                   365 Plus              167            2
#
# [891010 rows x 8 columns]

# %%
# Save Combined DataFrames to CSV
bike_share.to_csv("Vancouver_bikeshare.csv", index=False, header=True)
