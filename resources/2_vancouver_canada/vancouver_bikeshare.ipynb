# %% [markdown]
# # Import dependencies

# %%
import os 
import csv
import pandas as pd
import requests
import datetime as dt

# %% [markdown]
# # Data Files

# %%
vancouver_01_path = os.path.join("Resources","Mobi_System_Data_2019-01.csv")
vancouver_02_path = os.path.join("Resources","Mobi_System_Data_2019-02.csv")
vancouver_03_path = os.path.join("Resources","Mobi_System_Data_2019-03.csv")
vancouver_04_path = os.path.join("Resources","Mobi_System_Data_2019-04.csv")
vancouver_05_path = os.path.join("Resources","Mobi_System_Data_2019-05.csv")
vancouver_06_path = os.path.join("Resources","Mobi_System_Data_2019-06.csv")
vancouver_07_path = os.path.join("Resources","Mobi_System_Data_2019-07.csv")
vancouver_08_path = os.path.join("Resources","Mobi_System_Data_2019-08.csv")
vancouver_09_path = os.path.join("Resources","Mobi_System_Data_2019-09.csv")
vancouver_10_path = os.path.join("Resources","Mobi_System_Data_2019-10.csv")
vancouver_11_path = os.path.join("Resources","Mobi_System_Data_2019-11.csv")
vancouver_12_path = os.path.join("Resources","Mobi_System_Data_2019-12.csv")

# %% [markdown]
# # Read Data Files

# %%
vancouver_01 = pd.read_csv(vancouver_01_path, encoding="utf=8")
vancouver_02 = pd.read_csv(vancouver_02_path, encoding="utf=8")
vancouver_03 = pd.read_csv(vancouver_03_path, encoding="utf=8")
vancouver_04 = pd.read_csv(vancouver_04_path, encoding="utf=8")
vancouver_05 = pd.read_csv(vancouver_05_path, encoding="utf=8")
vancouver_06 = pd.read_csv(vancouver_06_path, encoding="utf=8")
vancouver_07 = pd.read_csv(vancouver_07_path, encoding="utf=8")
vancouver_08 = pd.read_csv(vancouver_08_path, encoding="utf=8")
vancouver_09 = pd.read_csv(vancouver_09_path, encoding="utf=8")
vancouver_10 = pd.read_csv(vancouver_10_path, encoding="utf=8")
vancouver_11 = pd.read_csv(vancouver_11_path, encoding="utf=8")
vancouver_12 = pd.read_csv(vancouver_12_path, encoding="utf=8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-608d4e129a5d> in <module>
# ----> 1 vancouver_01 = pd.read_csv(vancouver_01_path, encoding="utf=8")
#       2 vancouver_02 = pd.read_csv(vancouver_02_path, encoding="utf=8")
#       3 vancouver_03 = pd.read_csv(vancouver_03_path, encoding="utf=8")
#       4 vancouver_04 = pd.read_csv(vancouver_04_path, encoding="utf=8")
#       5 vancouver_05 = pd.read_csv(vancouver_05_path, encoding="utf=8")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1872         if kwds.get("compression") is None and encoding:
#    1873             if isinstance(src, str):
# -> 1874                 src = open(src, "rb")
#    1875                 self.handles.append(src)
#    1876
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/Mobi_System_Data_2019-01.csv'

# %%
vancouver_01
# Out:
#              Departure         Return    Bike  \
# 0        2/1/2019 0:00  2/1/2019 0:00   388.0
# 1        2/1/2019 0:00  2/1/2019 0:00  1880.0
# 2        2/1/2019 0:00  2/1/2019 0:00   779.0
# 3        2/1/2019 0:00  2/1/2019 0:00  2123.0
# 4      1/31/2019 23:00  2/1/2019 0:00   444.0
# ...                ...            ...     ...
# 36745    1/1/2019 0:00  1/1/2019 1:00   511.0
# 36746    1/1/2019 0:00  1/1/2019 0:00   723.0
# 36747    1/1/2019 0:00  1/1/2019 1:00   938.0
# 36748    1/1/2019 0:00  1/1/2019 0:00  1450.0
# 36749    1/1/2019 0:00  1/1/2019 1:00   161.0
#
#                      Departure station                  Return station  \
# 0                      0198 6th & Main             0298 6th & Carolina
# 1                   0193 Science World             0173 1st & Columbia
# 2              0063 Robson & Granville  0143 South False Creek Seawall
# 3                   0064 Expo & Smithe          0078 Nelson & Mainland
# 4               0060 Bidwell & Burnaby             0196 Drake & Hornby
# ...                                ...                             ...
# 36745  0105 Stanley Park - Totem Poles          0084 Sunset Beach West
# 36746              0088 Harwood & Bute          0218 Carrall & Seawall
# 36747               0139 Burrard & 4th         0167 Cordova & Columbia
# 36748              0088 Harwood & Bute          0218 Carrall & Seawall
# 36749          0098 Carrall & Hastings        0012 Dunsmuir & Richards
#
#               Membership type  Covered distance (m)  Duration (sec.)  \
# 0                365 Standard                 714.0              177
# 1                    365 Plus                 859.0              221
# 2      Vancity Community Pass                6691.0             3272
# 3      365 Day Pass Plus SALE                 473.0              157
# 4      365 Day Pass Plus SALE                1404.0              516
# ...                       ...                   ...              ...
# 36745                 24 Hour                4569.0             1382
# 36746  365 Corporate Standard                3689.0             1009
# 36747   365 Day Founding Plus                4737.0             1144
# 36748   365 Day Founding Plus                3702.0             1105
# 36749                 24 Hour                1686.0             1300
#
#        Departure battery voltage (mV)  Return battery voltage (mV)  \
# 0                                3826                         4000
# 1                                3705                         3850
# 2                                3842                         4059
# 3                                4029                         4140
# 4                                3990                         4100
# ...                               ...                          ...
# 36745                            4076                         4214
# 36746                            3750                         3969
# 36747                            3589                         3848
# 36748                            3568                         3876
# 36749                            3823                         3964
#
#        Departure temperature (C)  Return temperature (C)  Stopover duration  \
# 0                              9                       9                  0
# 1                              9                      11                  0
# 2                             10                      11                370
# 3                              9                      10                  0
# 4                              9                      10                  0
# ...                          ...                     ...                ...
# 36745                          4                       6                  0
# 36746                          5                       7                  0
# 36747                          5                       8                  0
# 36748                          5                       6                  0
# 36749                          5                       5                  0
#
#        Number of stopovers Manager
# 0                        0   False
# 1                        0   False
# 2                        1   False
# 3                        0   False
# 4                        0   False
# ...                    ...     ...
# 36745                    0   False
# 36746                    0   False
# 36747                    0   False
# 36748                    0   False
# 36749                    0   False
#
# [36750 rows x 15 columns]

# %%
# drop columns
columns=["Departure", "Return", "Bike", "Departure station", "Return station", 
         "Membership type", "Duration (sec.)"]
vancouver_01 = vancouver_01[columns]
# vancouver_02 = vancouver_02[columns]
# vancouver_02 = vancouver_02[columns]
# vancouver_03 = vancouver_03[columns]
# vancouver_04 = vancouver_04[columns]
# vancouver_05 = vancouver_05[columns]
# vancouver_06 = vancouver_06[columns]
# vancouver_07 = vancouver_07[columns]
# vancouver_08 = vancouver_08[columns]
# vancouver_09 = vancouver_09[columns]
# vancouver_10 = vancouver_10[columns]
# vancouver_11 = vancouver_11[columns]
# vancouver_12 = vancouver_12[columns]
# vancouver_12 = vancouver_12[columns]

# %%
vancouver_01
# Out:
#              Departure         Return    Bike  \
# 0        2/1/2019 0:00  2/1/2019 0:00   388.0
# 1        2/1/2019 0:00  2/1/2019 0:00  1880.0
# 2        2/1/2019 0:00  2/1/2019 0:00   779.0
# 3        2/1/2019 0:00  2/1/2019 0:00  2123.0
# 4      1/31/2019 23:00  2/1/2019 0:00   444.0
# ...                ...            ...     ...
# 36745    1/1/2019 0:00  1/1/2019 1:00   511.0
# 36746    1/1/2019 0:00  1/1/2019 0:00   723.0
# 36747    1/1/2019 0:00  1/1/2019 1:00   938.0
# 36748    1/1/2019 0:00  1/1/2019 0:00  1450.0
# 36749    1/1/2019 0:00  1/1/2019 1:00   161.0
#
#                      Departure station                  Return station  \
# 0                      0198 6th & Main             0298 6th & Carolina
# 1                   0193 Science World             0173 1st & Columbia
# 2              0063 Robson & Granville  0143 South False Creek Seawall
# 3                   0064 Expo & Smithe          0078 Nelson & Mainland
# 4               0060 Bidwell & Burnaby             0196 Drake & Hornby
# ...                                ...                             ...
# 36745  0105 Stanley Park - Totem Poles          0084 Sunset Beach West
# 36746              0088 Harwood & Bute          0218 Carrall & Seawall
# 36747               0139 Burrard & 4th         0167 Cordova & Columbia
# 36748              0088 Harwood & Bute          0218 Carrall & Seawall
# 36749          0098 Carrall & Hastings        0012 Dunsmuir & Richards
#
#               Membership type  Duration (sec.)
# 0                365 Standard              177
# 1                    365 Plus              221
# 2      Vancity Community Pass             3272
# 3      365 Day Pass Plus SALE              157
# 4      365 Day Pass Plus SALE              516
# ...                       ...              ...
# 36745                 24 Hour             1382
# 36746  365 Corporate Standard             1009
# 36747   365 Day Founding Plus             1144
# 36748   365 Day Founding Plus             1105
# 36749                 24 Hour             1300
#
# [36750 rows x 7 columns]

# %%
#performing concatenation
vancouver = [vancouver_01,vancouver_02,vancouver_03,vancouver_04,vancouver_05,vancouver_06,
             vancouver_07,vancouver_08,vancouver_09,vancouver_10,vancouver_11,vancouver_12]
bike_share = pd.concat(vancouver).drop_duplicates().reset_index(drop=True)
bike_share
# Out:
#               Departure           Return    Bike  \
# 0         2/1/2019 0:00    2/1/2019 0:00   388.0
# 1         2/1/2019 0:00    2/1/2019 0:00  1880.0
# 2         2/1/2019 0:00    2/1/2019 0:00   779.0
# 3         2/1/2019 0:00    2/1/2019 0:00  2123.0
# 4       1/31/2019 23:00    2/1/2019 0:00   444.0
# ...                 ...              ...     ...
# 891758  2019-12-01 0:00  2019-12-01 0:00   631.0
# 891759  2019-12-01 0:00  2019-12-01 1:00  1394.0
# 891760  2019-12-01 0:00  2019-12-01 0:00  1511.0
# 891761  2019-12-01 0:00  2019-12-01 0:00   985.0
# 891762  2019-12-01 0:00  2019-12-01 0:00   291.0
#
#                                Departure station  \
# 0                                0198 6th & Main
# 1                             0193 Science World
# 2                        0063 Robson & Granville
# 3                             0064 Expo & Smithe
# 4                         0060 Bidwell & Burnaby
# ...                                          ...
# 891758                         0187 Bute & Davie
# 891759                      0024 Hornby & Pender
# 891760  0099 Vancouver Art Gallery - North Plaza
# 891761                        0193 Science World
# 891762                        0193 Science World
#
#                           Return station         Membership type  \
# 0                    0298 6th & Carolina            365 Standard
# 1                    0173 1st & Columbia                365 Plus
# 2         0143 South False Creek Seawall  Vancity Community Pass
# 3                 0078 Nelson & Mainland  365 Day Pass Plus SALE
# 4                    0196 Drake & Hornby  365 Day Pass Plus SALE
# ...                                  ...                     ...
# 891758               0032 Comox & Denman                     NaN
# 891759  0208 Arbutus Greenway & Broadway                     NaN
# 891760              0096 Nicola & Robson                     NaN
# 891761               0174 1st & Manitoba                     NaN
# 891762               0174 1st & Manitoba                     NaN
#
#         Duration (sec.)            Membership Type  Covered distance (m)  \
# 0                   177                        NaN                   NaN
# 1                   221                        NaN                   NaN
# 2                  3272                        NaN                   NaN
# 3                   157                        NaN                   NaN
# 4                   516                        NaN                   NaN
# ...                 ...                        ...                   ...
# 891758              327                30 Day Pass                1084.0
# 891759             1473               365 Standard                4192.0
# 891760              358  365 Day Founding Standard                1292.0
# 891761              163                   365 Plus                 602.0
# 891762              167                   365 Plus                 608.0
#
#         Departure battery voltage (mV)  ...  Stopover duration  \
# 0                                  NaN  ...                NaN
# 1                                  NaN  ...                NaN
# 2                                  NaN  ...                NaN
# 3                                  NaN  ...                NaN
# 4                                  NaN  ...                NaN
# ...                                ...  ...                ...
# 891758                          3835.0  ...                NaN
# 891759                          3802.0  ...                NaN
# 891760                          3940.0  ...                NaN
# 891761                          3895.0  ...                NaN
# 891762                          3855.0  ...                NaN
#
#         Number of stopovers  Stopover duration (sec.)  Manager  \
# 0                       NaN                       NaN      NaN
# 1                       NaN                       NaN      NaN
# 2                       NaN                       NaN      NaN
# 3                       NaN                       NaN      NaN
# 4                       NaN                       NaN      NaN
# ...                     ...                       ...      ...
# 891758                  NaN                       0.0    False
# 891759                  NaN                       0.0    False
# 891760                  NaN                       0.0    False
# 891761                  NaN                       0.0    False
# 891762                  NaN                       0.0    False
#
#         Departure slot  Return slot Number of bike stopovers  \
# 0                  NaN          NaN                      NaN
# 1                  NaN          NaN                      NaN
# 2                  NaN          NaN                      NaN
# 3                  NaN          NaN                      NaN
# 4                  NaN          NaN                      NaN
# ...                ...          ...                      ...
# 891758             NaN          NaN                      0.0
# 891759             NaN          NaN                      0.0
# 891760             NaN          NaN                      0.0
# 891761             NaN          NaN                      0.0
# 891762             NaN          NaN                      0.0
#
#         Departure temperature (°C)  Return temperature (°C)  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4                              NaN                      NaN
# ...                            ...                      ...
# 891758                         1.0                      NaN
# 891759                         4.0                      NaN
# 891760                         3.0                      NaN
# 891761                         0.0                      NaN
# 891762                         1.0                      NaN
#
#         Return temperature (Â°C)
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 891758                       2.0
# 891759                       2.0
# 891760                       5.0
# 891761                       2.0
# 891762                       2.0
#
# [891763 rows x 23 columns]

# %%
# remove rows with null values
bike_share = bike_share.dropna()

# %%
bike_share
# Out:
# Empty DataFrame
# Columns: [Departure, Return, Bike, Departure station, Return station, Membership type, Duration (sec.), Membership Type, Covered distance (m), Departure battery voltage (mV), Return battery voltage (mV), Departure temperature (C), Return temperature (C), Stopover duration, Number of stopovers, Stopover duration (sec.), Manager, Departure slot, Return slot, Number of bike stopovers, Departure temperature (°C), Return temperature (°C), Return temperature (Â°C)]
# Index: []
#
# [0 rows x 23 columns]

# %%
#Add new column:location_id
vancouver_01["location_id"]=2
vancouver_02["location_id"]=2
vancouver_03["location_id"]=2
vancouver_04["location_id"]=2
vancouver_05["location_id"]=2
vancouver_06["location_id"]=2
vancouver_07["location_id"]=2
vancouver_08["location_id"]=2
vancouver_09["location_id"]=2
vancouver_10["location_id"]=2
vancouver_11["location_id"]=2
vancouver_12["location_id"]=2

# %%
vancouver_01
# Out:
#              Departure         Return    Bike  \
# 0        2/1/2019 0:00  2/1/2019 0:00   388.0
# 1        2/1/2019 0:00  2/1/2019 0:00  1880.0
# 2        2/1/2019 0:00  2/1/2019 0:00   779.0
# 3        2/1/2019 0:00  2/1/2019 0:00  2123.0
# 4      1/31/2019 23:00  2/1/2019 0:00   444.0
# ...                ...            ...     ...
# 36745    1/1/2019 0:00  1/1/2019 1:00   511.0
# 36746    1/1/2019 0:00  1/1/2019 0:00   723.0
# 36747    1/1/2019 0:00  1/1/2019 1:00   938.0
# 36748    1/1/2019 0:00  1/1/2019 0:00  1450.0
# 36749    1/1/2019 0:00  1/1/2019 1:00   161.0
#
#                      Departure station                  Return station  \
# 0                      0198 6th & Main             0298 6th & Carolina
# 1                   0193 Science World             0173 1st & Columbia
# 2              0063 Robson & Granville  0143 South False Creek Seawall
# 3                   0064 Expo & Smithe          0078 Nelson & Mainland
# 4               0060 Bidwell & Burnaby             0196 Drake & Hornby
# ...                                ...                             ...
# 36745  0105 Stanley Park - Totem Poles          0084 Sunset Beach West
# 36746              0088 Harwood & Bute          0218 Carrall & Seawall
# 36747               0139 Burrard & 4th         0167 Cordova & Columbia
# 36748              0088 Harwood & Bute          0218 Carrall & Seawall
# 36749          0098 Carrall & Hastings        0012 Dunsmuir & Richards
#
#               Membership type  Duration (sec.)  location_id
# 0                365 Standard              177            2
# 1                    365 Plus              221            2
# 2      Vancity Community Pass             3272            2
# 3      365 Day Pass Plus SALE              157            2
# 4      365 Day Pass Plus SALE              516            2
# ...                       ...              ...          ...
# 36745                 24 Hour             1382            2
# 36746  365 Corporate Standard             1009            2
# 36747   365 Day Founding Plus             1144            2
# 36748   365 Day Founding Plus             1105            2
# 36749                 24 Hour             1300            2
#
# [36750 rows x 8 columns]

# %%
# remove rows with null values
bike_share = bike_share.dropna()

# %%
bike_share
# Out:
# Empty DataFrame
# Columns: [Departure, Return, Bike, Departure station, Return station, Membership type, Duration (sec.), Membership Type, Covered distance (m), Departure battery voltage (mV), Return battery voltage (mV), Departure temperature (C), Return temperature (C), Stopover duration, Number of stopovers, Stopover duration (sec.), Manager, Departure slot, Return slot, Number of bike stopovers, Departure temperature (°C), Return temperature (°C), Return temperature (Â°C)]
# Index: []
#
# [0 rows x 23 columns]

# %%
#Bike ID
bikes = pd.DataFrame(bike_share[["location_id"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-8a78c21deaf6> in <module>
#       1 #Bike ID
# ----> 2 bikes = pd.DataFrame(bike_share[["location_id"]])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['location_id'], dtype='object')] are in the [columns]"

# %%
bikes

# %%
# Combine Data into Quarters (Q1. Q2, Q3, Q4)
q1 = pd.concat([vancouver_01, vancouver_02, vancouver_03], ignore_index=True)
q2 = pd.concat([vancouver_04, vancouver_05, vancouver_06], ignore_index=True)
q3 = pd.concat([vancouver_07, vancouver_08, vancouver_09], ignore_index=True)
q4 = pd.concat([vancouver_10, vancouver_11, vancouver_12], ignore_index=True)

# %%
q1

# %%
#drop bad dates
q1= q1.loc[(q1["Return"]!= "1900-01-00 0:00")]
q2= q2.loc[(q2["Return"]!= "1900-01-00 0:00")]
q3= q3.loc[(q3["Return"]!= "1900-01-00 0:00")]
q4= q4.loc[(q4["Return"]!= "1900-01-00 0:00")]

# %%
# Display Data Table for Preview - Q1
q1["Member Type"]=q1["Membership type"]
q2["Member Type"]=q2["Membership type"]
q3["Member Type"]=q3["Membership type"]
q4["Member Type"]=q4["Membership type"]


#.replace()
q1=q1.replace({"Membership type":{"365 Standard": "Annual Member", 
               "365 Plus": "Annual Member", 
               "Vancity Community Pass": "Annual Member", 
               "365 Day Pass Plus SALE": "Annual Member",
               "365 Day Founding Standard": "Annual Member",
               "365 Day Pass Standard SALE": "Annual Member", 
              "365 Standard": "Annual Member", 
              "365 Corporate Standard": "Annual Member", 
              "365 Corporate Plus": "Annual Member",
               "365 Day Founding Plus": "Annual Member", 
               "Archived Monthly Plus": "Monthly Member",
               "Archived Monthly Basic": "Monthly Member",
               "365 Corporate Standard Renewal": "Annual Member", 
                "Archived Monthly Standard": "Monthly Member",
             "365 Corporate Plus Renewal": "Annual Member", 
               "24 Hour": "Casual Member",
               "VIP": "Casual Member",
               "30 Day Pass": "Annual Member",
               "Single Trip Pass": "Casual Member",
               "Shared Mobility Pass": "Casual Member",
               "Archived 90 Day": "90 Day"}})

q2=q2.replace({"Membership type":{"365 Standard": "Annual Member", 
               "365 Plus": "Annual Member", 
               "Vancity Community Pass": "Annual Member", 
               "365 Day Pass Plus SALE": "Annual Member",
               "365 Day Founding Standard": "Annual Member",
               "365 Day Pass Standard SALE": "Annual Member", 
              "365 Standard": "Annual Member", 
              "365 Corporate Standard": "Annual Member", 
              "365 Corporate Plus": "Annual Member",
               "365 Day Founding Plus": "Annual Member", 
               "Archived Monthly Plus": "Monthly Member",
               "Archived Monthly Basic": "Monthly Member",
               "365 Corporate Standard Renewal": "Annual Member", 
                "Archived Monthly Standard": "Monthly Member",
             "365 Corporate Plus Renewal": "Annual Member", 
               "24 Hour": "Casual Member",
               "VIP": "Casual Member",
               "30 Day Pass": "Annual Member",
               "Single Trip Pass": "Casual Member",
               "Shared Mobility Pass": "Casual Member",
               "Archived 90 Day": "90 Day"}})
q3=q3.replace({"Membership type":{"365 Standard": "Annual Member", 
               "365 Plus": "Annual Member", 
               "Vancity Community Pass": "Annual Member", 
               "365 Day Pass Plus SALE": "Annual Member",
               "365 Day Founding Standard": "Annual Member",
               "365 Day Pass Standard SALE": "Annual Member", 
              "365 Standard": "Annual Member", 
              "365 Corporate Standard": "Annual Member", 
              "365 Corporate Plus": "Annual Member",
               "365 Day Founding Plus": "Annual Member", 
               "Archived Monthly Plus": "Monthly Member",
               "Archived Monthly Basic": "Monthly Member",
               "365 Corporate Standard Renewal": "Annual Member", 
                "Archived Monthly Standard": "Monthly Member",
             "365 Corporate Plus Renewal": "Annual Member", 
               "24 Hour": "Casual Member",
               "VIP": "Casual Member",
               "30 Day Pass": "Annual Member",
               "Single Trip Pass": "Casual Member",
               "Shared Mobility Pass": "Casual Member",
               "Archived 90 Day": "90 Day"}})
q4=q4.replace({"Membership type":{"365 Standard": "Annual Member", 
               "365 Plus": "Annual Member", 
               "Vancity Community Pass": "Annual Member", 
               "365 Day Pass Plus SALE": "Annual Member",
               "365 Day Founding Standard": "Annual Member",
               "365 Day Pass Standard SALE": "Annual Member", 
              "365 Standard": "Annual Member", 
              "365 Corporate Standard": "Annual Member", 
              "365 Corporate Plus": "Annual Member",
               "365 Day Founding Plus": "Annual Member", 
               "Archived Monthly Plus": "Monthly Member",
               "Archived Monthly Basic": "Monthly Member",
               "365 Corporate Standard Renewal": "Annual Member", 
                "Archived Monthly Standard": "Monthly Member",
             "365 Corporate Plus Renewal": "Annual Member", 
               "24 Hour": "Casual Member",
               "VIP": "Casual Member",
               "30 Day Pass": "Annual Member",
               "Single Trip Pass": "Casual Member",
               "Shared Mobility Pass": "Casual Member",
               "Archived 90 Day": "90 Day"}})

# %%
# drop columns
i =["Member Type"]

q1=q1.drop(columns=i)
q2=q2.drop(columns=i)
q3=q3.drop(columns=i)
q4=q4.drop(columns=i)

# %%
q1

# %%
#Membership :User type
usertype = pd.DataFrame(bike_share[["Membership type","location_id"]])
usertype = usertype.drop_duplicates().reset_index(drop=True)

# %%
usertype
