# %% [markdown]
# # Import dependencies

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import requests
import datetime as dt

# %% [markdown]
# # Study data files

# %%
# ny files
ny_01_path = os.path.join("Resources","jan_2019.csv")
ny_02_path = os.path.join("Resources","feb_2019.csv")
ny_03_path = os.path.join("Resources","march_2019.csv")
ny_04_path = os.path.join("Resources","april_2019.csv")
ny_03_path = os.path.join("Resources","may_2019.csv")
ny_05_path = os.path.join("Resources","june_2019.csv")
ny_06_path = os.path.join("Resources","july_2019.csv")
ny_07_path = os.path.join("Resources","august_2019.csv")
ny_08_path = os.path.join("Resources","sept_2019.csv")
ny_09_path = os.path.join("Resources","oct_2019.csv")
ny_10_path = os.path.join("Resources","nov_2019.csv")
ny_11_path = os.path.join("Resources","dec_2019.csv")

# %% [markdown]
# # Read the data and study the results

# %%
q1 = pd.read_csv(ny_01_path, encoding="utf=8")
q2 = pd.read_csv(ny_02_path, encoding="utf=8")
q3 = pd.read_csv(ny_03_path, encoding="utf=8")
q4 = pd.read_csv(ny_04_path, encoding="utf=8")
q5 = pd.read_csv(ny_05_path, encoding="utf=8")
q6 = pd.read_csv(ny_06_path, encoding="utf=8")
q7 = pd.read_csv(ny_07_path, encoding="utf=8")
q8 = pd.read_csv(ny_08_path, encoding="utf=8")
q9 = pd.read_csv(ny_09_path, encoding="utf=8")
q10 = pd.read_csv(ny_10_path, encoding="utf=8")
q11 = pd.read_csv(ny_11_path, encoding="utf=8")

# %%
q1
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                  88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1                 443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2                 662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3                  86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4                 136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
# ...               ...                       ...                       ...
# 1766089           516  2019-04-30 23:59:33.7520  2019-05-01 00:08:10.1700
# 1766090           435  2019-04-30 23:59:35.0850  2019-05-01 00:06:50.4610
# 1766091           564  2019-04-30 23:59:40.1050  2019-05-01 00:09:04.3660
# 1766092           675  2019-04-30 23:59:43.2650  2019-05-01 00:10:58.6670
# 1766093          1764  2019-04-30 23:59:50.8000  2019-05-01 00:29:15.0230
#
#          start station id          start station name  start station latitude  \
# ...
