# %% [markdown]
# # Import dependencies

# %%
import os
import pandas as pd
import datetime as dt

# %% [markdown]
# # Study data files

# %%
# ny files
ny_01_path = os.path.join("Resources","jan_2019.csv")
ny_02_path = os.path.join("Resources","feb_2019.csv")
ny_03_path = os.path.join("Resources","march_2019.csv")
ny_04_path = os.path.join("Resources","april_2019.csv")
ny_05_path = os.path.join("Resources","may_2019.csv")
ny_06_path = os.path.join("Resources","june_2019.csv")
ny_07_path = os.path.join("Resources","july_2019.csv")
ny_08_path = os.path.join("Resources","august_2019.csv")
ny_09_path = os.path.join("Resources","sept_2019.csv")
ny_10_path = os.path.join("Resources","oct_2019.csv")
ny_11_path = os.path.join("Resources","nov_2019.csv")
ny_12_path = os.path.join("Resources","dec_2019.csv")

# %% [markdown]
# # Read the data and study the results

# %%
ny_01 = pd.read_csv(ny_01_path, encoding="utf=8")
ny_02 = pd.read_csv(ny_02_path, encoding="utf=8")
ny_03 = pd.read_csv(ny_03_path, encoding="utf=8")
ny_04 = pd.read_csv(ny_04_path, encoding="utf=8")
ny_05 = pd.read_csv(ny_05_path, encoding="utf=8")
ny_06 = pd.read_csv(ny_06_path, encoding="utf=8")
ny_07 = pd.read_csv(ny_07_path, encoding="utf=8")
ny_08 = pd.read_csv(ny_08_path, encoding="utf=8")
ny_09 = pd.read_csv(ny_09_path, encoding="utf=8")
ny_10 = pd.read_csv(ny_10_path, encoding="utf=8")
ny_11 = pd.read_csv(ny_11_path, encoding="utf=8")
ny_12 = pd.read_csv(ny_12_path, encoding="utf=8")

# %%
ny_01
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1               1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4               1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...              ...                       ...                       ...
# 955205            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 955206           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 955207           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id                start station name  \
# ...

# %%
# drop columns
i =["birth year","gender","start station latitude","start station longitude","end station latitude",
    "end station longitude","end station name","start station name"]

ny_01=ny_01.drop(columns=i)
ny_02=ny_02.drop(columns=i)
ny_03=ny_03.drop(columns=i)
ny_04=ny_04.drop(columns=i)
ny_05=ny_05.drop(columns=i)
ny_06=ny_06.drop(columns=i)
ny_07=ny_07.drop(columns=i)
ny_08=ny_08.drop(columns=i)
ny_09=ny_09.drop(columns=i)
ny_10=ny_10.drop(columns=i)
ny_11=ny_11.drop(columns=i)
ny_12=ny_12.drop(columns=i)

# %%
#Add new column:location_id
ny_01["location_id"]=4
ny_02["location_id"]=4
ny_03["location_id"]=4
ny_04["location_id"]=4
ny_05["location_id"]=4
ny_06["location_id"]=4
ny_07["location_id"]=4
ny_08["location_id"]=4
ny_09["location_id"]=4
ny_10["location_id"]=4
ny_11["location_id"]=4
ny_12["location_id"]=4

# %%
ny_01
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1               1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4               1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...              ...                       ...                       ...
# 955205            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 955206           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 955207           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id  end station id  bikeid    usertype  location_id
# ...

# %%
#usertype:annual=subscriber(3),casual=customer(4)

ny_01=ny_01.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_02=ny_02.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_03=ny_03.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_04=ny_04.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_05=ny_05.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_06=ny_06.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_07=ny_07.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_08=ny_08.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_09=ny_09.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_10=ny_10.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_11=ny_11.replace({"usertype":{"Subscriber":3,"Customer":4}})
ny_12=ny_12.replace({"usertype":{"Subscriber":3,"Customer":4}})

# %%
ny_01
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1               1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4               1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...              ...                       ...                       ...
# 955205            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 955206           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 955207           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 955208          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 955209           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#         start station id  end station id  bikeid  usertype  location_id
# ...

# %%
#performing concatenation
new_york = [ny_01,ny_02,ny_03,ny_03,ny_03,ny_04,ny_05,ny_06,ny_06,ny_07,ny_08,ny_09,ny_10,ny_11,ny_12]
bike_share = pd.concat(new_york).drop_duplicates().reset_index(drop=True)
bike_share
# Out:
#           tripduration                 starttime                  stoptime  \
# 0                  602  2019-12-01 00:00:05.5640  2019-12-01 00:10:07.8180
# 1                 1206  2019-12-01 00:00:10.9630  2019-12-01 00:20:17.8820
# 2                  723  2019-12-01 00:00:11.8180  2019-12-01 00:12:14.8310
# 3                  404  2019-12-01 00:00:12.2200  2019-12-01 00:06:56.8860
# 4                 1059  2019-12-01 00:00:14.7230  2019-12-01 00:17:54.1860
# ...                ...                       ...                       ...
# 20551692           534  2019-11-30 23:59:07.8070  2019-12-01 00:08:01.9840
# 20551693           269  2019-11-30 23:59:14.4120  2019-12-01 00:03:43.6630
# 20551694           668  2019-11-30 23:59:26.4970  2019-12-01 00:10:35.2200
# 20551695           450  2019-11-30 23:59:28.5170  2019-12-01 00:06:58.7670
# 20551696           811  2019-11-30 23:59:50.4100  2019-12-01 00:13:22.3840
#
# ...

# %%
# remove rows with null values
ny_01 = ny_01.dropna()
ny_02 = ny_02.dropna()
ny_03 = ny_03.dropna()
ny_04 = ny_04.dropna()
ny_05 = ny_05.dropna()
ny_06 = ny_06.dropna()
ny_07 = ny_07.dropna()
ny_08 = ny_08.dropna()
ny_09 = ny_09.dropna()
ny_10 = ny_10.dropna()
ny_11 = ny_11.dropna()
ny_12 = ny_12.dropna()

# %%
#Bike ID
bikes01 = pd.DataFrame(ny_01[["bikeid","location_id"]])
bikes02 = pd.DataFrame(ny_02[["bikeid","location_id"]])
bikes03 = pd.DataFrame(ny_03[["bikeid","location_id"]])
bikes04 = pd.DataFrame(ny_04[["bikeid","location_id"]])
bikes05 = pd.DataFrame(ny_05[["bikeid","location_id"]])
bikes06 = pd.DataFrame(ny_06[["bikeid","location_id"]])
bikes07 = pd.DataFrame(ny_07[["bikeid","location_id"]])
bikes08 = pd.DataFrame(ny_08[["bikeid","location_id"]])
bikes09 = pd.DataFrame(ny_09[["bikeid","location_id"]])
bikes10 = pd.DataFrame(ny_10[["bikeid","location_id"]])
bikes11 = pd.DataFrame(ny_11[["bikeid","location_id"]])
bikes12 = pd.DataFrame(ny_12[["bikeid","location_id"]])

# %%
frames = [bikes01, bikes02, bikes03, bikes04, bikes05, bikes06, bikes07,
          bikes08, bikes09, bikes10, bikes11, bikes12]
bikes = pd.concat(frames).drop_duplicates().reset_index(drop=True)

bikes.columns=["BikeID", "LocationID"]
bikes
# Out:
#        BikeID  LocationID
# 0       41932           4
# 1       18869           4
# 2       15334           4
# 3       41692           4
# 4       40156           4
# ...       ...         ...
# 19534   29296           4
# 19535   29441           4
# 19536   26200           4
# 19537   42088           4
# 19538   26422           4
#
# [19539 rows x 2 columns]

# %%
#User type
user01 = pd.DataFrame(ny_01[["usertype","location_id"]])
user02 = pd.DataFrame(ny_02[["usertype","location_id"]])
user03 = pd.DataFrame(ny_03[["usertype","location_id"]])
user04 = pd.DataFrame(ny_04[["usertype","location_id"]])
user05 = pd.DataFrame(ny_05[["usertype","location_id"]])
user06 = pd.DataFrame(ny_06[["usertype","location_id"]])
user07 = pd.DataFrame(ny_07[["usertype","location_id"]])
user08 = pd.DataFrame(ny_08[["usertype","location_id"]])
user09 = pd.DataFrame(ny_09[["usertype","location_id"]])
user10 = pd.DataFrame(ny_10[["usertype","location_id"]])
user11 = pd.DataFrame(ny_11[["usertype","location_id"]])
user12 = pd.DataFrame(ny_12[["usertype","location_id"]])

# %%
frames = [user01, user02, user03, user04, user05, user06, user07,
         user08, user09, user10, user11,user12]
usertype= pd.concat(frames).drop_duplicates().reset_index(drop=True)

usertype.columns=["UserType", "LocationID"]
usertype
# Out:
#    UserType  LocationID
# 0         3           4
# 1         4           4
