# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

from config import conn_string

# %% [markdown]
# **get all files for loading**

# %%
# path
station_path = os.path.join('.', "station_info.csv")
weather_path = os.path.join('.', "historical_weather.csv")

#bikes
toronto_bikes = os.path.join("Resources/1_toronto_canada", "toronto_bikes.csv")
vancouver_bikes = os.path.join("Resources/2_vancouver_canada", "vancouver_bikes.csv")
boston_bikes = os.path.join("Resources/3_boston_us", "boston_bikes.csv")
nyc_bikes = os.path.join("Resources/4_NewYork_US", "nyc_bikes.csv")

# membertypes
toronto_users = os.path.join("Resources/1_toronto_canada", "toronto_membertypes.csv")
vancouver_users = os.path.join("Resources/2_vancouver_canada", "vancouver_membertypes.csv")
boston_users = os.path.join("Resources/3_boston_us", "boston_membertypes.csv")
nyc_users = os.path.join("Resources/4_NewYork_US", "nyc_membertypes.csv")

# ridership
toronto_ = os.path.join("Resources/1_toronto_canada", "toronto_bikeshare.csv")
vancouver_ = os.path.join("Resources/2_vancouver_canada", "vancouver_bikeshare.csv")
boston_ = os.path.join("Resources/3_boston_us", "boston_bikeshare.csv")
nyc_ = os.path.join("Resources/4_NewYork_US", "nyc_bikeshare.csv")

# %%
# read files
stns = pd.read_csv(station_path, encoding="utf-8")
weather = pd.read_csv(weather_path, encoding="utf-8")

# bikes
tor_bikes = pd.read_csv(toronto_bikes, encoding="utf-8")
van_bikes = pd.read_csv(vancouver_bikes, encoding="utf-8")
bos_bikes = pd.read_csv(boston_bikes, encoding="utf-8")
nyc_bikes = pd.read_csv(nyc_bikes, encoding="utf-8")

# member_types
tor_users = pd.read_csv(toronto_users, encoding="utf-8")
van_users = pd.read_csv(vancouver_users, encoding="utf-8")
bos_users = pd.read_csv(boston_users, encoding="utf-8")
nyc_users = pd.read_csv(nyc_users, encoding="utf-8")

# pricing index


# ridership
toronto = pd.read_csv(toronto_, encoding="utf-8")
vancouver = pd.read_csv(vancouver_, encoding="utf-8")
boston = pd.read_csv(boston_, encoding="utf-8")
newyork = pd.read_csv(nyc_, encoding="utf-8")

# %% [markdown]
# **Locations**

# %%
# create locations table
locations = [{"location_id": 1,"city":"Toronto", "country":"Canada" }, 
             {"location_id": 2,"city":"Vancouver", "country":"Canada"},
             {"location_id": 3,"city":"Boston", "country":"USA"},
             {"location_id": 4,"city":"New York", "country":"USA"}
            ]

df = pd.DataFrame(locations)
df.set_index("location_id", inplace=True)
df
# Out:
#                   city country
# location_id
# 1              Toronto  Canada
# 2            Vancouver  Canada
# 3               Boston     USA
# 4             New York     USA

# %% [markdown]
# **Stations**

# %%
stns.head()
# Out:
#    station_id                     station_name   latitude  longitude  \
# 0        7000     Fort York  Blvd / Capreol Ct  43.639832 -79.395954
# 1        7001  Lower Jarvis St / The Esplanade  43.647830 -79.370698
# 2        7002       St. George St / Bloor St W  43.667333 -79.399429
# 3        7003         Madison Ave / Bloor St W  43.667158 -79.402761
# 4        7004          University Ave / Elm St  43.656518 -79.389099
#
#    location_id
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %% [markdown]
# **Historical Weather**

# %%
weather.head()
# Out:
#    location_id forecast_date  maxtempc  humidity  total_precip  \
# 0            1    2019-01-01         1    77.250           3.6
# 1            1    2019-01-02        -5    69.000           0.2
# 2            1    2019-01-03        -1    68.500           1.3
# 3            1    2019-01-04         2    77.250           0.0
# 4            1    2019-01-05         3    81.125           0.0
#
#    avg_cloudcover  avg_windspeed
# 0          50.625         16.875
# 1          41.750          8.625
# 2          68.250         17.750
# 3           7.625         18.125
# 4          23.750         11.250

# %% [markdown]
# **Bikes**

# %%
tor_bikes.head()
# Out:
#    bike_id  location_id
# 0     1296            1
# 1     2947            1
# 2     2293            1
# 3      283            1
# 4     1799            1

# %%
van_bikes.head()
# Out:
#    bike_id  location_id
# 0    388.0            2
# 1   1880.0            2
# 2    779.0            2
# 3   2123.0            2
# 4    444.0            2

# %%
bos_bikes.head()
# Out:
#    bike_id  location_id
# 0     3689            3
# 1     4142            3
# 2     1628            3
# 3     2969            3
# 4     3469            3

# %%
nyc_bikes.head()
# Out:
#    bike_id  location_id
# 0    15839            4
# 1    32723            4
# 2    27451            4
# 3    21579            4
# 4    35379            4

# %% [markdown]
# **Member Types**

# %%
tor_users.head()
# Out:
#      member_type  location_id
# 0  Annual Member            1
# 1  Casual Member            1

# %%
van_users.head()
# Out:
#                  member_type  location_id
# 0               365 Standard            2
# 1                   365 Plus            2
# 2     Vancity Community Pass            2
# 3     365 Day Pass Plus SALE            2
# 4  365 Day Founding Standard            2

# %%
bos_users.head()
# Out:
#   member_type  location_id
# 0  Subscriber            3
# 1    Customer            3

# %%
nyc_users.head()
# Out:
#   member_type  location_id
# 0  Subscriber            4
# 1    Customer            4

# %% [markdown]
# **Pricing Index**

# %% [markdown]
# **Ridership**

# %%
# Toronto
toronto.head()
# Out:
#    trip_duration        start_date          end_date  start_station_id  \
# 0           1547  01/01/2019 00:08  01/01/2019 00:33              7021
# 1           1112  01/01/2019 00:10  01/01/2019 00:29              7160
# 2            589  01/01/2019 00:15  01/01/2019 00:25              7055
# 3            259  01/01/2019 00:16  01/01/2019 00:20              7012
# 4            281  01/01/2019 00:19  01/01/2019 00:24              7041
#
#    end_station_id  bike_id    member_type  location_id
# 0            7233     1296  Annual Member            1
# 1            7051     2947  Annual Member            1
# 2            7013     2293  Annual Member            1
# 3            7235      283  Annual Member            1
# 4            7257     1799  Annual Member            1

# %%
# Vancouver
vancouver.head()
# Out:
#    trip_duration       start_date       end_date  start_station_id  \
# 0            177    2/1/2019 0:00  2/1/2019 0:00               198
# 1            221    2/1/2019 0:00  2/1/2019 0:00               193
# 2           3272    2/1/2019 0:00  2/1/2019 0:00                63
# 3            157    2/1/2019 0:00  2/1/2019 0:00                64
# 4            516  1/31/2019 23:00  2/1/2019 0:00                60
#
#    end_station_id  bike_id             member_type  location_id
# 0             298    388.0            365 Standard            2
# 1             173   1880.0                365 Plus            2
# 2             143    779.0  Vancity Community Pass            2
# 3              78   2123.0  365 Day Pass Plus SALE            2
# 4             196    444.0  365 Day Pass Plus SALE            2

# %%
# Boston
boston.head()
# Out:
#    trip_duration                start_date                  end_date  \
# 0            371  2019-01-01 00:09:13.7980  2019-01-01 00:15:25.3360
# 1            264  2019-01-01 00:33:56.1820  2019-01-01 00:38:20.8800
# 2            458  2019-01-01 00:41:54.6000  2019-01-01 00:49:33.2730
# 3            364  2019-01-01 00:43:32.5710  2019-01-01 00:49:37.4260
# 4            681  2019-01-01 00:49:56.4640  2019-01-01 01:01:17.7010
#
#    start_station_id  end_station_id  bike_id member_type  location_id
# 0                80             179     3689  Subscriber            3
# 1               117             189     4142  Subscriber            3
# 2                68              96     1628  Subscriber            3
# 3                89             334     2969  Subscriber            3
# 4                73             367     3469  Subscriber            3

# %%
# New York
newyork.head()
# Out:
#    trip_duration                start_date                  end_date  \
# 0            320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1            316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2            591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3           2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4            303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#    start_station_id  end_station_id  bike_id member_type  location_id
# 0            3160.0          3283.0    15839  Subscriber            4
# 1             519.0           518.0    32723  Subscriber            4
# 2            3171.0          3154.0    27451  Subscriber            4
# 3             504.0          3709.0    21579  Subscriber            4
# 4             229.0           503.0    35379  Subscriber            4

# %% [markdown]
# #### Load data

# %%
# connect to database
cnx = f'postgresql://{conn_string}'
engine = create_engine(cnx)

# %%
# confirm tables
engine.table_names()
# Out:
# ['locations',
#  'membertypes',
#  'stations',
#  'bikes',
#  'ridership',
#  'pricing',
#  'historicalweather']

# %%
# load locations into database
df.to_sql(name='locations', con=engine, if_exists='append', index=True)

# %%
# load stations into database
stns.to_sql(name='stations', con=engine, if_exists='append', index=False)

# %%
# load historical weather into database
weather.to_sql(name='historicalweather', con=engine, if_exists='append', index=False)

# %%
# load toronto bikes into database
tor_bikes.to_sql(name='bikes', con=engine, if_exists='append', index=False)

# %%
# load vancouver bikes into database
van_bikes.to_sql(name='bikes', con=engine, if_exists='append', index=False)

# %%
# load boston bikes into database
bos_bikes.to_sql(name='bikes', con=engine, if_exists='append', index=False)

# %%
# load new york bikes into database
nyc_bikes.to_sql(name='bikes', con=engine, if_exists='append', index=False)

# %%
# load toronto member types
tor_users.to_sql(name='membertypes', con=engine, if_exists='append', index=False)

# %%
# load vancouver member types
van_users.to_sql(name='membertypes', con=engine, if_exists='append', index=False)

# %%
# load boston member types
bos_users.to_sql(name='membertypes', con=engine, if_exists='append', index=False)

# %%
# load new york member types
nyc_users.to_sql(name='membertypes', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Load Ridership

# %%
# check reference to stations table
# create session
session = Session(bind=engine)
# declare a base using automap_base
Base = automap_base()
# use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
Stations = Base.classes.stations

# %% [markdown]
# ***Verify that all station_ids used in bikeshare exists in Stations table***

# %%
# get all stations
all_stations = session.query(Stations.station_id).all()
all_stns_df = pd.DataFrame(all_stations)
all_stns_df
# Out:
#       station_id
# 0           7000
# 1           7001
# 2           7002
# 3           7003
# 4           7004
# ...          ...
# 2396        4248
# 2397        4249
# 2398        4250
# 2399        4252
# 2400        4253
#
# [2401 rows x 1 columns]

# %% [markdown]
# ### ***Toronto***

# %%
# check for Toronto records with start_station_id not in stations table
missing_start = toronto[-toronto["start_station_id"].isin(all_stns_df["station_id"])]
missing_start = missing_start.rename(columns={"start_station_id":"station_id"})

# %%
missing_start
# Out:
# Empty DataFrame
# Columns: [trip_duration, start_date, end_date, station_id, end_station_id, bike_id, member_type, location_id]
# Index: []

# %%
# check for Toronto records with end_station_id not in stations table
missing_end = toronto[-toronto["end_station_id"].isin(all_stns_df["station_id"])]
missing_end = missing_end.rename(columns={"start_station_id":"station_id"})

# %%
missing_end
# Out:
# Empty DataFrame
# Columns: [trip_duration, start_date, end_date, station_id, end_station_id, bike_id, member_type, location_id]
# Index: []

# %% [markdown]
# *Load rows with station_id existing in stations table*

# %%
toronto = toronto[toronto["start_station_id"].isin(all_stns_df["station_id"])]
toronto = toronto[toronto["end_station_id"].isin(all_stns_df["station_id"])]

# %%
toronto
# Out:
#        trip_duration        start_date          end_date  start_station_id  \
# 0               1547  01/01/2019 00:08  01/01/2019 00:33              7021
# 1               1112  01/01/2019 00:10  01/01/2019 00:29              7160
# 2                589  01/01/2019 00:15  01/01/2019 00:25              7055
# 3                259  01/01/2019 00:16  01/01/2019 00:20              7012
# 4                281  01/01/2019 00:19  01/01/2019 00:24              7041
# ...              ...               ...               ...               ...
# 99995            465  02/27/2019 07:03  02/27/2019 07:11              7320
# 99996            360  02/27/2019 07:04  02/27/2019 07:10              7143
# 99997            447  02/27/2019 07:05  02/27/2019 07:12              7054
# 99998            407  02/27/2019 07:05  02/27/2019 07:12              7031
# 99999           1097  02/27/2019 07:07  02/27/2019 07:26              7211
#
#        end_station_id  bike_id    member_type  location_id
# 0                7233     1296  Annual Member            1
# 1                7051     2947  Annual Member            1
# 2                7013     2293  Annual Member            1
# 3                7235      283  Annual Member            1
# 4                7257     1799  Annual Member            1
# ...               ...      ...            ...          ...
# 99995            7323     3729  Annual Member            1
# 99996            7252     3641  Annual Member            1
# 99997            7033     1091  Annual Member            1
# 99998            7129     1028  Annual Member            1
# 99999            7047      120  Annual Member            1
#
# [100000 rows x 8 columns]

# %%
# get all Toronto stations
stns_toronto = session.query(Stations.station_id).filter(Stations.location_id==1).all()
stns_toronto = pd.DataFrame(stns_toronto)
stns_toronto = stns_toronto.rename(columns={"station_id": "start_station_id"})
stns_toronto
# Out:
#      start_station_id
# 0                7000
# 1                7001
# 2                7002
# 3                7003
# 4                7004
# ..                ...
# 602              7660
# 603              7662
# 604              7663
# 605              7664
# 606              7665
#
# [607 rows x 1 columns]

# %%
# remove Toronto records with start_station_id not in stations table
tor_df = pd.merge(toronto, stns_toronto, how='inner', on='start_station_id')

# %%
tor_df
# Out:
#        trip_duration        start_date          end_date  start_station_id  \
# 0               1547  01/01/2019 00:08  01/01/2019 00:33              7021
# 1                453  01/01/2019 10:35  01/01/2019 10:42              7021
# 2                632  01/01/2019 14:13  01/01/2019 14:24              7021
# 3                234  01/01/2019 19:05  01/01/2019 19:09              7021
# 4                843  01/02/2019 09:14  01/02/2019 09:28              7021
# ...              ...               ...               ...               ...
# 99995           1255  02/02/2019 14:24  02/02/2019 14:45              7345
# 99996           1240  02/02/2019 14:24  02/02/2019 14:45              7345
# 99997           1226  02/03/2019 15:23  02/03/2019 15:43              7345
# 99998           1515  02/04/2019 16:06  02/04/2019 16:31              7345
# 99999            931  02/22/2019 14:33  02/22/2019 14:48              7345
#
#        end_station_id  bike_id    member_type  location_id
# 0                7233     1296  Annual Member            1
# 1                7253     1118  Annual Member            1
# 2                7323      111  Annual Member            1
# 3                7052      942  Annual Member            1
# 4                7036     1814  Annual Member            1
# ...               ...      ...            ...          ...
# 99995            7076     3156  Casual Member            1
# 99996            7076     1233  Casual Member            1
# 99997            7108     2974  Annual Member            1
# 99998            7313      851  Annual Member            1
# 99999            7099     3731  Casual Member            1
#
# [100000 rows x 8 columns]

# %%
# rename Toronto station column to check if end_station_id exists in stations table
stns_toronto = stns_toronto.rename(columns={"start_station_id": "end_station_id"})
stns_toronto
# Out:
#      end_station_id
# 0              7000
# 1              7001
# 2              7002
# 3              7003
# 4              7004
# ..              ...
# 602            7660
# 603            7662
# 604            7663
# 605            7664
# 606            7665
#
# [607 rows x 1 columns]

# %%
#remove Toronto records with end_station_id not in stations table
toronto = pd.merge(tor_df, stns_toronto, how='inner', on='end_station_id')

# %%
# count number of records for insert to ridership table
toronto.count()
# Out:
# trip_duration       100000
# start_date          100000
# end_date            100000
# start_station_id    100000
# end_station_id      100000
# bike_id             100000
# member_type         100000
# location_id         100000
# dtype: int64

# %%
# Load Toronto bikeshare data to ridership table
toronto.to_sql(name='ridership', con=engine, if_exists='append', index=False, index_label='id')

# %% [markdown]
# ### ***Vancouver***

# %%
# check for Vancouver records with start_station_id missing in stations table
missing_start = vancouver[-vancouver["start_station_id"].isin(all_stns_df["station_id"])]
missing_start = missing_start.rename(columns={"start_station_id":"station_id"})

# %%
missing_start
# Out:
#        trip_duration       start_date         end_date  station_id  \
# 8712              28  1/25/2019 18:00  1/25/2019 18:00         990
# 9630             170   1/25/2019 9:00   1/25/2019 9:00         990
# 11715             30  1/23/2019 17:00  1/23/2019 17:00         991
# 12212           1600  1/23/2019 11:00  1/23/2019 11:00         990
# 12238             34  1/23/2019 10:00  1/23/2019 10:00         990
# 12249             26  1/23/2019 10:00  1/23/2019 10:00         991
# 12273            642  1/23/2019 10:00  1/23/2019 10:00         990
# 14000           5510  1/21/2019 14:00  1/21/2019 16:00         990
# 14005           5755  1/21/2019 14:00  1/21/2019 16:00         990
# 15203            768  1/20/2019 15:00  1/20/2019 16:00         990
# 15757           2014  1/20/2019 11:00  1/20/2019 12:00         990
# 19981            369  1/16/2019 15:00  1/16/2019 15:00         990
# 22810           1959  1/14/2019 12:00  1/14/2019 13:00         990
# 28385            491  1/10/2019 16:00  1/10/2019 16:00         990
# 30255             23   1/8/2019 17:00   1/8/2019 17:00         990
# 30341            934   1/8/2019 15:00   1/8/2019 15:00         990
# 31624           3736   1/7/2019 15:00   1/7/2019 16:00         990
# 32360            513   1/6/2019 22:00   1/6/2019 22:00         990
# 32447            951   1/6/2019 19:00   1/6/2019 19:00         990
# 34590            158   1/4/2019 12:00   1/4/2019 12:00         990
#
#        end_station_id  bike_id                 member_type  location_id
# 8712              990   1306.0                         VIP            2
# 9630              225   1412.0                         VIP            2
# 11715             990    681.0                         VIP            2
# 12212              54    412.0                         VIP            2
# 12238             990    412.0                         VIP            2
# 12249             991    412.0                         VIP            2
# 12273               6    843.0      365 Day Pass Plus SALE            2
# 14000              72   1775.0                    365 Plus            2
# 14005              72   1127.0                    365 Plus            2
# 15203             254    504.0                         VIP            2
# 15757             990    504.0                         VIP            2
# 19981             285    620.0                         VIP            2
# 22810             990    620.0                         VIP            2
# 28385              12   1346.0  365 Day Pass Standard SALE            2
# 30255             990    944.0                         VIP            2
# 30341             990    900.0                         VIP            2
# 31624             991   1055.0                         VIP            2
# 32360             150   1060.0                         VIP            2
# 32447             990   1060.0                         VIP            2
# 34590             225    817.0                         VIP            2

# %%
# check for Vancouver records with end_station_id missing in stations table
missing_end = vancouver[-vancouver["end_station_id"].isin(all_stns_df["station_id"])]
missing_end = missing_end.rename(columns={"start_station_id":"station_id"})

# %%
missing_end
# Out:
#        trip_duration       start_date         end_date  station_id  \
# 1215            1035   1/31/2019 8:00   1/31/2019 8:00         107
# 4437             662   1/29/2019 6:00   1/29/2019 6:00         242
# 5764             885   1/28/2019 8:00   1/28/2019 9:00          15
# 5805            4839   1/28/2019 8:00   1/28/2019 9:00         254
# 5811            1208   1/28/2019 8:00   1/28/2019 8:00         206
# 6544             706  1/27/2019 14:00  1/27/2019 14:00         150
# 8712              28  1/25/2019 18:00  1/25/2019 18:00         990
# 9575             186  1/25/2019 10:00  1/25/2019 10:00         225
# 11715             30  1/23/2019 17:00  1/23/2019 17:00         991
# 12238             34  1/23/2019 10:00  1/23/2019 10:00         990
# 12249             26  1/23/2019 10:00  1/23/2019 10:00         991
# 12666          53178  1/22/2019 20:00  1/23/2019 11:00           1
# 12851           3367  1/22/2019 15:00  1/22/2019 15:00           5
# 13078           1350   1/22/2019 8:00   1/22/2019 9:00          72
# 13902            924  1/21/2019 15:00  1/21/2019 15:00          12
# 14019            620  1/21/2019 14:00  1/21/2019 14:00         150
# 14540           1329   1/21/2019 9:00   1/21/2019 9:00          72
# 14628          12412   1/21/2019 8:00  1/21/2019 12:00         254
# 15416            610  1/20/2019 14:00  1/20/2019 14:00         150
# 15757           2014  1/20/2019 11:00  1/20/2019 12:00         990
# 16611            702  1/19/2019 14:00  1/19/2019 14:00          11
# 18230           8549   1/18/2019 8:00  1/18/2019 11:00         242
# 18412          11564  1/17/2019 19:00  1/17/2019 22:00         218
# 18818           1411  1/17/2019 14:00  1/17/2019 14:00         235
# 19187            133   1/17/2019 9:00   1/17/2019 9:00         223
# 19244           3310   1/17/2019 8:00   1/17/2019 9:00         242
# 19262           7339   1/17/2019 8:00  1/17/2019 10:00          60
# 19709          17256  1/16/2019 18:00  1/16/2019 22:00          99
# 20060           1224  1/16/2019 14:00  1/16/2019 14:00         235
# 20459           4341   1/16/2019 9:00  1/16/2019 10:00         242
# 22651            569  1/14/2019 14:00  1/14/2019 14:00         150
# 22810           1959  1/14/2019 12:00  1/14/2019 13:00         990
# 23228           7176   1/14/2019 8:00  1/14/2019 10:00         254
# 23247          32052   1/14/2019 8:00  1/14/2019 17:00          72
# 24119            667  1/13/2019 14:00  1/13/2019 14:00         150
# 24662           5258  1/13/2019 10:00  1/14/2019 17:00         153
# 25562            835  1/12/2019 14:00  1/12/2019 14:00         150
# 27701          11917   1/11/2019 8:00  1/11/2019 12:00         254
# 28736          15295  1/10/2019 12:00  1/10/2019 16:00         240
# 28933            841   1/10/2019 9:00   1/10/2019 9:00         262
# 28985           4977   1/10/2019 8:00  1/10/2019 10:00         242
# 29606            737   1/9/2019 14:00   1/9/2019 14:00          11
# 29913           2969    1/9/2019 8:00    1/9/2019 9:00         254
# 29946           2725    1/9/2019 8:00    1/9/2019 9:00          72
# 30255             23   1/8/2019 17:00   1/8/2019 17:00         990
# 30341            934   1/8/2019 15:00   1/8/2019 15:00         990
# 30877           1503    1/8/2019 8:00    1/8/2019 8:00          72
# 31624           3736   1/7/2019 15:00   1/7/2019 16:00         990
# 31696            606   1/7/2019 14:00   1/7/2019 14:00         150
# 32231           1505    1/7/2019 8:00    1/7/2019 8:00          72
# 32447            951   1/6/2019 19:00   1/6/2019 19:00         990
# 32757            867   1/6/2019 14:00   1/6/2019 14:00         150
# 34007            929    1/5/2019 6:00    1/5/2019 6:00          11
# 34733           1364    1/4/2019 9:00   1/4/2019 10:00          72
# 35441            856   1/2/2019 14:00   1/2/2019 14:00          11
#
#        end_station_id  bike_id            member_type  location_id
# 1215              990   1542.0                    VIP            2
# 4437              990    235.0                    VIP            2
# 5764              990    824.0                    VIP            2
# 5805              991   1623.0                    VIP            2
# 5811              990   1133.0                    VIP            2
# 6544              990   1034.0                    VIP            2
# 8712              990   1306.0                    VIP            2
# 9575              990   1412.0                    VIP            2
# 11715             990    681.0                    VIP            2
# 12238             990    412.0                    VIP            2
# 12249             991    412.0                    VIP            2
# 12666             991    993.0           365 Standard            2
# 12851             990    843.0                    VIP            2
# 13078             990    434.0                    VIP            2
# 13902             990    188.0                    VIP            2
# 14019             990   1775.0                    VIP            2
# 14540             990   1410.0                    VIP            2
# 14628             991    539.0                    VIP            2
# 15416             990   1296.0                    VIP            2
# 15757             990    504.0                    VIP            2
# 16611             990   1127.0               365 Plus            2
# 18230             991   1441.0                    VIP            2
# 18412             990    584.0               365 Plus            2
# 18818             990   1629.0                    VIP            2
# 19187             990    504.0                    VIP            2
# 19244             991    258.0                    VIP            2
# 19262             991   1346.0  Archived Monthly Plus            2
# 19709             990    681.0                    VIP            2
# 20060             990   1113.0                    VIP            2
# 20459             991   2011.0                    VIP            2
# 22651             990   1864.0                    VIP            2
# 22810             990    620.0                    VIP            2
# 23228             991    960.0                    VIP            2
# 23247             991    977.0                    VIP            2
# 24119             990   1288.0                    VIP            2
# 24662             990    884.0                    VIP            2
# 25562             990   1116.0                    VIP            2
# 27701             991   1778.0                    VIP            2
# 28736             991    224.0                    VIP            2
# 28933             990   2129.0                    VIP            2
# 28985             991    634.0                    VIP            2
# 29606             990    180.0                    VIP            2
# 29913             991    706.0                    VIP            2
# 29946             991   1395.0                    VIP            2
# 30255             990    944.0                    VIP            2
# 30341             990    900.0                    VIP            2
# 30877             990    983.0                    VIP            2
# 31624             991   1055.0                    VIP            2
# 31696             990   1055.0                    VIP            2
# 32231             990   1452.0                    VIP            2
# 32447             990   1060.0                    VIP            2
# 32757             990    423.0                    VIP            2
# 34007             991   1280.0                    VIP            2
# 34733             990   1815.0                    VIP            2
# 35441             990   2045.0                    VIP            2

# %%
# check Vancouver records with start_station_id and end_station_id existing in stations table
vancouver = vancouver[vancouver["start_station_id"].isin(all_stns_df["station_id"])]
vancouver = vancouver[vancouver["end_station_id"].isin(all_stns_df["station_id"])]

# %%
vancouver
# Out:
#        trip_duration       start_date       end_date  start_station_id  \
# 0                177    2/1/2019 0:00  2/1/2019 0:00               198
# 1                221    2/1/2019 0:00  2/1/2019 0:00               193
# 2               3272    2/1/2019 0:00  2/1/2019 0:00                63
# 3                157    2/1/2019 0:00  2/1/2019 0:00                64
# 4                516  1/31/2019 23:00  2/1/2019 0:00                60
# ...              ...              ...            ...               ...
# 36740           1382    1/1/2019 0:00  1/1/2019 1:00               105
# 36741           1009    1/1/2019 0:00  1/1/2019 0:00                88
# 36742           1144    1/1/2019 0:00  1/1/2019 1:00               139
# 36743           1105    1/1/2019 0:00  1/1/2019 0:00                88
# 36744           1300    1/1/2019 0:00  1/1/2019 1:00                98
#
#        end_station_id  bike_id             member_type  location_id
# 0                 298    388.0            365 Standard            2
# 1                 173   1880.0                365 Plus            2
# 2                 143    779.0  Vancity Community Pass            2
# 3                  78   2123.0  365 Day Pass Plus SALE            2
# 4                 196    444.0  365 Day Pass Plus SALE            2
# ...               ...      ...                     ...          ...
# 36740              84    511.0                 24 Hour            2
# 36741             218    723.0  365 Corporate Standard            2
# 36742             167    938.0   365 Day Founding Plus            2
# 36743             218   1450.0   365 Day Founding Plus            2
# 36744              12    161.0                 24 Hour            2
#
# [36680 rows x 8 columns]

# %%
# get all Vancouver stations
stns_vancouver = session.query(Stations.station_id).filter(Stations.location_id==2).all()
stns_vancouver = pd.DataFrame(stns_vancouver)
stns_vancouver = stns_vancouver.rename(columns={"station_id": "start_station_id"})
stns_vancouver
# Out:
#      start_station_id
# 0                   1
# 1                   2
# 2                   4
# 3                   5
# 4                   6
# ..                ...
# 197               285
# 198               287
# 199               297
# 200               298
# 201               300
#
# [202 rows x 1 columns]

# %%
# remove Vancouver records with start_station_id not in stations table
vancouver_df = pd.merge(vancouver, stns_vancouver, how='inner', on='start_station_id')

# %%
# rename Vancouver station column to end_station_id
stns_vancouver = stns_vancouver.rename(columns={"start_station_id": "end_station_id"})
stns_vancouver.head()
# Out:
#    end_station_id
# 0               1
# 1               2
# 2               4
# 3               5
# 4               6

# %%
#remove Vancouver records with end_station_id not in stations table
vancouver = pd.merge(vancouver_df, stns_vancouver, how='inner', on='end_station_id')

# %%
# check number of records for insert to database
vancouver.count()
# Out:
# trip_duration       36680
# start_date          36680
# end_date            36680
# start_station_id    36680
# end_station_id      36680
# bike_id             36680
# member_type         36680
# location_id         36680
# dtype: int64

# %%
# Load Vancouver bikeshare data to ridership table
vancouver.to_sql(name='ridership', con=engine, if_exists='append', index=False, index_label='id')

# %% [markdown]
# ### ***Boston***

# %%
# check Boston data for missing start_station_id
missing_start = boston[-boston["start_station_id"].isin(all_stns_df["station_id"])]
missing_start
# Out:
#        trip_duration                start_date                  end_date  \
# 215              610  2019-01-01 11:05:52.2480  2019-01-01 11:16:02.6380
# 302             1657  2019-01-01 11:59:53.3000  2019-01-01 12:27:30.3620
# 306             1509  2019-01-01 12:02:14.3990  2019-01-01 12:27:24.3260
# 486             1874  2019-01-01 13:13:17.7800  2019-01-01 13:44:32.1500
# 488             1854  2019-01-01 13:13:35.4750  2019-01-01 13:44:29.5620
# ...              ...                       ...                       ...
# 69339            365  2019-01-31 17:35:58.4630  2019-01-31 17:42:03.9100
# 69375            448  2019-01-31 17:45:04.7500  2019-01-31 17:52:33.3280
# 69566           1308  2019-01-31 18:49:23.9190  2019-01-31 19:11:12.3160
# 69615            443  2019-01-31 19:14:51.1830  2019-01-31 19:22:14.8730
# 69746            491  2019-01-31 20:45:33.2650  2019-01-31 20:53:45.1340
#
#        start_station_id  end_station_id  bike_id member_type  location_id
# 215                  42              40     2648  Subscriber            3
# 302                  42              65     3553    Customer            3
# 306                  42              65     2790    Customer            3
# 486                  42              42     4118    Customer            3
# 488                  42              42     4441    Customer            3
# ...                 ...             ...      ...         ...          ...
# 69339                42              22     4462  Subscriber            3
# 69375                42             190     2269  Subscriber            3
# 69566                42             139     4463  Subscriber            3
# 69615                42               6     4467    Customer            3
# 69746                42              25     3698  Subscriber            3
#
# [315 rows x 8 columns]

# %%
# check for missing end_station_id
missing_end = boston[-boston["end_station_id"].isin(all_stns_df["station_id"])]
missing_end
# Out:
#        trip_duration                start_date                  end_date  \
# 44               622  2019-01-01 06:06:01.8390  2019-01-01 06:16:24.1470
# 226             1646  2019-01-01 11:11:29.5610  2019-01-01 11:38:55.9730
# 227             1596  2019-01-01 11:11:43.6340  2019-01-01 11:38:20.4030
# 261              959  2019-01-01 11:31:57.0740  2019-01-01 11:47:56.1730
# 316             1043  2019-01-01 12:08:56.8120  2019-01-01 12:26:20.0560
# ...              ...                       ...                       ...
# 69296            228  2019-01-31 17:28:19.5150  2019-01-31 17:32:07.7730
# 69405            323  2019-01-31 17:52:26.5220  2019-01-31 17:57:50.2330
# 69480            252  2019-01-31 18:19:35.3470  2019-01-31 18:23:47.8430
# 69516            309  2019-01-31 18:28:31.2450  2019-01-31 18:33:40.6540
# 69733            143  2019-01-31 20:35:26.8240  2019-01-31 20:37:50.3490
#
#        start_station_id  end_station_id  bike_id member_type  location_id
# 44                  157              42     4553  Subscriber            3
# 226                 356              42     2423    Customer            3
# 227                 356              42     2790    Customer            3
# 261                 105              42     3955  Subscriber            3
# 316                 178              42     4371    Customer            3
# ...                 ...             ...      ...         ...          ...
# 69296                36              42     4462  Subscriber            3
# 69405               374              42     3415  Subscriber            3
# 69480               374              42     4355  Subscriber            3
# 69516                16              42     2601  Subscriber            3
# 69733                81              42     3820  Subscriber            3
#
# [407 rows x 8 columns]

# %%
boston = boston[boston["start_station_id"].isin(all_stns_df["station_id"])]
boston = boston[boston["end_station_id"].isin(all_stns_df["station_id"])]
boston
# Out:
#        trip_duration                start_date                  end_date  \
# 0                371  2019-01-01 00:09:13.7980  2019-01-01 00:15:25.3360
# 1                264  2019-01-01 00:33:56.1820  2019-01-01 00:38:20.8800
# 2                458  2019-01-01 00:41:54.6000  2019-01-01 00:49:33.2730
# 3                364  2019-01-01 00:43:32.5710  2019-01-01 00:49:37.4260
# 4                681  2019-01-01 00:49:56.4640  2019-01-01 01:01:17.7010
# ...              ...                       ...                       ...
# 69867            431  2019-01-31 23:48:35.5680  2019-01-31 23:55:47.0140
# 69868            567  2019-01-31 23:49:11.7920  2019-01-31 23:58:39.3080
# 69869            420  2019-01-31 23:49:55.6920  2019-01-31 23:56:55.7720
# 69870            249  2019-01-31 23:51:19.3780  2019-01-31 23:55:28.9770
# 69871          60560  2019-01-28 00:51:13.0960  2019-01-28 17:40:33.9460
#
#        start_station_id  end_station_id  bike_id member_type  location_id
# 0                    80             179     3689  Subscriber            3
# 1                   117             189     4142  Subscriber            3
# 2                    68              96     1628  Subscriber            3
# 3                    89             334     2969  Subscriber            3
# 4                    73             367     3469  Subscriber            3
# ...                 ...             ...      ...         ...          ...
# 69867                81              23     2696  Subscriber            3
# 69868               178             116     3010  Subscriber            3
# 69869               108              87     3676  Subscriber            3
# 69870                68             178     2203  Subscriber            3
# 69871                68             363     3801  Subscriber            3
#
# [69175 rows x 8 columns]

# %%
# get all Boston stations
stns_boston = session.query(Stations.station_id).filter(Stations.location_id==3).all()
stns_boston = pd.DataFrame(stns_boston)
stns_boston = stns_boston.rename(columns={"station_id": "start_station_id"})
stns_boston
# Out:
#      start_station_id
# 0                   3
# 1                   4
# 2                   5
# 3                   6
# 4                   7
# ..                ...
# 373               495
# 374               496
# 375               497
# 376               498
# 377               499
#
# [378 rows x 1 columns]

# %%
# remove Boston records with start_station_id not in stations table
df = pd.merge(boston, stns_boston, how='inner', on='start_station_id')

# %%
# rename Boston station column to end_station_id
stns_boston = stns_boston.rename(columns={"start_station_id": "end_station_id"})
stns_boston.head()
# Out:
#    end_station_id
# 0               3
# 1               4
# 2               5
# 3               6
# 4               7

# %%
#remove Boston records with end_station_id not in stations table
boston_df = pd.merge(df, stns_boston, how='inner', on='end_station_id')

# %%
# count number of Boston records for insert to ridership table
boston_df.count()
# Out:
# trip_duration       68210
# start_date          68210
# end_date            68210
# start_station_id    68210
# end_station_id      68210
# bike_id             68210
# member_type         68210
# location_id         68210
# dtype: int64

# %%
# load Boston records to ridership table
boston_df.to_sql(name='ridership', con=engine, if_exists='append', index=False, index_label='id')

# %% [markdown]
# ### ***New York***

# %%
# check for New York records with missing start_station_id in stations table
missing_start = newyork[-newyork["start_station_id"].isin(all_stns_df["station_id"])]
missing_start
# Out:
#        trip_duration                start_date                  end_date  \
# 6                280  2019-01-01 00:09:21.0060  2019-01-01 00:14:01.1510
# 72               740  2019-01-01 00:42:16.3560  2019-01-01 00:54:36.8120
# 97               967  2019-01-01 00:50:10.0810  2019-01-01 01:06:17.7230
# 138              207  2019-01-01 01:00:48.7520  2019-01-01 01:04:15.8860
# 143              642  2019-01-01 01:01:34.8600  2019-01-01 01:12:17.7070
# ...              ...                       ...                       ...
# 99956            467  2019-01-03 21:40:06.5770  2019-01-03 21:47:54.1780
# 99965            139  2019-01-03 21:40:54.0590  2019-01-03 21:43:13.1320
# 99971            125  2019-01-03 21:41:20.4860  2019-01-03 21:43:26.2770
# 99992            610  2019-01-03 21:42:59.7330  2019-01-03 21:53:10.0820
# 99999            470  2019-01-03 21:43:29.4870  2019-01-03 21:51:20.3550
#
#        start_station_id  end_station_id  bike_id member_type  location_id
# 6                3675.0          3288.0    35391  Subscriber            4
# 72                524.0           526.0    34089  Subscriber            4
# 97                524.0           236.0    35052  Subscriber            4
# 138              3360.0          3434.0    25854  Subscriber            4
# 143              3341.0          3529.0    28933  Subscriber            4
# ...                 ...             ...      ...         ...          ...
# 99956            3631.0           436.0    29558  Subscriber            4
# 99965             382.0          3463.0    35075  Subscriber            4
# 99971             243.0           298.0    35636  Subscriber            4
# 99992            3660.0          3255.0    33448    Customer            4
# 99999            3474.0           312.0    28394  Subscriber            4
#
# [6889 rows x 8 columns]

# %%
# check for New York records with missing end_station_id in stations table
missing_end = newyork[-newyork["end_station_id"].isin(all_stns_df["station_id"])]
missing_end
# Out:
#        trip_duration                start_date                  end_date  \
# 1                316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 18               829  2019-01-01 00:19:08.1030  2019-01-01 00:32:57.3880
# 20               736  2019-01-01 00:21:02.9570  2019-01-01 00:33:19.4110
# 28              1068  2019-01-01 00:25:13.8750  2019-01-01 00:43:01.9350
# 58               187  2019-01-01 00:35:03.5980  2019-01-01 00:38:10.6250
# ...              ...                       ...                       ...
# 99903            509  2019-01-03 21:37:30.1870  2019-01-03 21:46:00.1730
# 99904            333  2019-01-03 21:37:26.4860  2019-01-03 21:42:59.9570
# 99909            388  2019-01-03 21:37:41.5310  2019-01-03 21:44:09.7860
# 99914            307  2019-01-03 21:38:13.3420  2019-01-03 21:43:20.4560
# 99963           2073  2019-01-03 21:40:34.8330  2019-01-03 22:15:08.6960
#
#        start_station_id  end_station_id  bike_id member_type  location_id
# 1                 519.0           518.0    32723  Subscriber            4
# 18               3165.0          3295.0    32106  Subscriber            4
# 20               3165.0          3295.0    16761    Customer            4
# 28                394.0          3431.0    32042  Subscriber            4
# 58                484.0           524.0    34089  Subscriber            4
# ...                 ...             ...      ...         ...          ...
# 99903             340.0          3701.0    35319  Subscriber            4
# 99904             174.0          3431.0    32840  Subscriber            4
# 99909            3284.0          3168.0    28117  Subscriber            4
# 99914            3435.0          3474.0    27723  Subscriber            4
# 99963             369.0          3660.0    34918  Subscriber            4
#
# [6643 rows x 8 columns]

# %%
# check New York records with start_station_id and end_station_id both in stations table
newyork = newyork[newyork["start_station_id"].isin(all_stns_df["station_id"])]
newyork = newyork[newyork["end_station_id"].isin(all_stns_df["station_id"])]
newyork
# Out:
#        trip_duration                start_date                  end_date  \
# 0                320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 2                591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3               2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# 5                535  2019-01-01 00:08:33.1790  2019-01-01 00:17:28.3540
# ...              ...                       ...                       ...
# 99994            774  2019-01-03 21:42:58.5580  2019-01-03 21:55:52.7160
# 99995             61  2019-01-03 21:43:05.5590  2019-01-03 21:44:06.8270
# 99996            523  2019-01-03 21:43:19.0950  2019-01-03 21:52:02.7520
# 99997           1179  2019-01-03 21:43:13.7950  2019-01-03 22:02:53.6280
# 99998            292  2019-01-03 21:43:18.7030  2019-01-03 21:48:10.7200
#
#        start_station_id  end_station_id  bike_id member_type  location_id
# 0                3160.0          3283.0    15839  Subscriber            4
# 2                3171.0          3154.0    27451  Subscriber            4
# 3                 504.0          3709.0    21579  Subscriber            4
# 4                 229.0           503.0    35379  Subscriber            4
# 5                3630.0          3529.0    30315  Subscriber            4
# ...                 ...             ...      ...         ...          ...
# 99994             276.0           223.0    33988  Subscriber            4
# 99995            3137.0          3137.0    20902  Subscriber            4
# 99996             476.0           507.0    18518  Subscriber            4
# 99997            3158.0          3383.0    16710    Customer            4
# 99998             462.0           453.0    26943  Subscriber            4
#
# [87064 rows x 8 columns]

# %%
# get New York stations data
stns_newyork = session.query(Stations.station_id).filter(Stations.location_id==4).all()
stns_newyork = pd.DataFrame(stns_newyork)
stns_newyork = stns_newyork.rename(columns={"station_id": "start_station_id"})
stns_newyork
# Out:
#       start_station_id
# 0                 3477
# 1                   72
# 2                   79
# 3                   82
# 4                   83
# ...                ...
# 1209              4248
# 1210              4249
# 1211              4250
# 1212              4252
# 1213              4253
#
# [1214 rows x 1 columns]

# %%
# remove New York records with start_station_id not existing in stations table
ny_df = pd.merge(newyork, stns_newyork, how='inner', on='start_station_id')

# %%
# rename New Yorks stations column to end_station_id
stns_newyork = stns_newyork.rename(columns={"start_station_id": "end_station_id"})
stns_newyork.head()
# Out:
#    end_station_id
# 0            3477
# 1              72
# 2              79
# 3              82
# 4              83

# %%
# remove New York records with end_station_id not existing in stations table
newyork_df = pd.merge(ny_df, stns_newyork, how='inner', on='end_station_id')

# %%
# count number of New York records for insert to ridership table
newyork_df.count()
# Out:
# trip_duration       81231
# start_date          81231
# end_date            81231
# start_station_id    81231
# end_station_id      81231
# bike_id             81231
# member_type         81231
# location_id         81231
# dtype: int64

# %%
newyork_df.to_sql(name='ridership', con=engine, if_exists='append', index=False, index_label='id')
